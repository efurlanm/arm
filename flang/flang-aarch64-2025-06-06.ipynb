# %% [markdown]
# # Flang [AArch64](https://en.wikipedia.org/wiki/AArch64)
#
# 2025-06-06
#
# My personal notes on Flang AArch64
#
# - [Flang](https://flang.llvm.org/docs/) release [20.1.6](https://github.com/llvm/llvm-project/releases/tag/llvmorg-20.1.6)
# - Moto G4 with [Android 9.0_r44 ARM64 AOSiP](https://forum.xda-developers.com/t/rom-9-0_r44-arm64-android-open-source-illusion-project-athene-unofficial.3889942/)
# - Processor: Snapdragon 617 octa-core ARMv8 Cortex-A53 64-bit

# %%
! jupyter-lab --version
# Out:
# 4.4.3

# %%
! termux-info
# Out:
# Termux Variables:
# TERMUX_APK_RELEASE=F_DROID
# TERMUX_APP_PACKAGE_MANAGER=apt
# TERMUX_APP_PID=15008
# TERMUX_APP__DATA_DIR=/data/user/0/com.termux
# TERMUX_APP__LEGACY_DATA_DIR=/data/data/com.termux
# TERMUX_APP__SE_FILE_CONTEXT=u:object_r:app_data_file:s0:c124,c256,c512,c768
# TERMUX_APP__SE_INFO=default:targetSdkVersion=28:complete
# TERMUX_IS_DEBUGGABLE_BUILD=0
# TERMUX_MAIN_PACKAGE_FORMAT=debian
# TERMUX_VERSION=0.118.3
# TERMUX__HOME=/data/data/com.termux/files/home
# TERMUX__PREFIX=/data/data/com.termux/files/usr
# TERMUX__ROOTFS_DIR=/data/data/com.termux/files
# TERMUX__SE_PROCESS_CONTEXT=u:r:untrusted_app:s0:c124,c256,c512,c768
# TERMUX__USER_ID=0
# Packages CPU architecture:
# aarch64
# Subscribed repositories:
# # sources.list
# deb https://packages-cf.termux.dev/apt/termux-main stable main
# Updatable packages:
# All packages up to date
# termux-tools version:
# 1.45.0
# Android version:
# 9
# Kernel build information:
# Linux localhost 3.10.108-lk.r17_rev #5 SMP PREEMPT Sun Dec 4 17:05:47 IST 2022 aarch64 Android
# Device manufacturer:
# Motorola
# Device model:
# Moto G4
# Supported ABIs:
# SUPPORTED_ABIS: arm64-v8a,armeabi-v7a,armeabi
# SUPPORTED_32_BIT_ABIS: armeabi-v7a,armeabi
# SUPPORTED_64_BIT_ABIS: arm64-v8a
# LD Variables:
# LD_LIBRARY_PATH=
# LD_PRELOAD=/data/data/com.termux/files/usr/lib/libtermux-exec-ld-preload.so

# %%
! inxi
# Out:
# CPU: 2x 4-core AArch64 (-MCP AMP-) speed/min/max: 332/499:403/1651:1210 MHz
# Kernel: 3.10.108-lk.r17_rev aarch64 Up: 4d 6h 16m Mem: 1.07/1.8 GiB (59.2%)
# Storage: 14.56 GiB (237.8% used) Procs: 10 Shell: python3.12 inxi: 3.3.38

# %%
! nproc --all
# Out:
# 8

# %%
! lscpu
# Out:
# Architecture:            aarch64
#   CPU op-mode(s):        32-bit, 64-bit
#   Byte Order:            Little Endian
# CPU(s):                  8
#   On-line CPU(s) list:   0,2,4-7
#   Off-line CPU(s) list:  1,3
# Vendor ID:               ARM
#   Model name:            Cortex-A53
#     Model:               4
#     Thread(s) per core:  1
#     Core(s) per cluster: 3
#     Socket(s):           -
#     Cluster(s):          2
#     Stepping:            r0p4
#     CPU(s) scaling MHz:  52%
#     CPU max MHz:         1651.2000
#     CPU min MHz:         0.0000
#     Flags:               fp asimd evtstrm aes pmull sha1 sha2 crc32

# %%
! cat /proc/cpuinfo
# Out:
# Processor	: AArch64 Processor rev 4 (aarch64)
# processor	: 0
# processor	: 1
# processor	: 2
# processor	: 3
# processor	: 4
# processor	: 5
# processor	: 6
# processor	: 7
# Features	: fp asimd evtstrm aes pmull sha1 sha2 crc32
# CPU implementer	: 0x41
# CPU architecture: 8
# CPU variant	: 0x0
# CPU part	: 0xd03
# CPU revision	: 4
#
# Hardware	: Qualcomm Technologies, Inc MSM8952
# Revision	: 82ad
# Serial		: a740b00000000000
# Device		: athene_13mp
# Radio		: Brazil
# MSM Hardware	: MSM8952

# %% [markdown]
# Feature | Description
# - | -
# fp 	    | floating point (VFPv4) present
# asimd 	| advanced SIMD (Neon) present
# evtstrm | timer event stream generation
# aes 	| AESD and AESE instructions
# pmull 	| PMULL, PMULL2 instructions
# sha1 	| SHA1* instructions
# sha2 	| SHA256* instructions
# crc32 	| CRC32* instructions

# %% [markdown]
# - ARM Cortex-A53 implements the ARMv8-A 64-bit instruction set
# - 2-wide decode superscalar processor, capable of dual-issuing some instructions
# - VFPv4 has 32 64-bit FPU registers and fused multiply-accumulate instructions, per core
# - In Neon, the SIMD
#     - supports up to 16 operations at the same time
#     - shares the same floating-point registers as used in VFP
#     - support 128-bit vectors, but will execute with 64 bits at a time
#     - gcc needs -funsafe-math-optimizations to work with

# %%
! pkg show flang
# Out:
# Package: flang
# Version: 20.1.6
# Maintainer: @termux
# Installed-Size: 917 MB
# Depends: libandroid-complex-math-static, libc++, libllvm (= 20.1.6-0), clang (= 20.1.6-0), lld (= 20.1.6-0), mlir (= 20.1.6-0)
# Homepage: https://flang.llvm.org/
# Download-Size: 58.6 MB
# APT-Manual-Installed: yes
# APT-Sources: https://packages-cf.termux.dev/apt/termux-main stable/main aarch64 Packages
# Description: LLVM's Fortran frontend

# %%
! flang --version
# Out:
# flang version 20.1.6
# Target: aarch64-unknown-linux-android24
# Thread model: posix
# InstalledDir: /data/data/com.termux/files/usr/bin

# %% [markdown]
# \
# from https://fortran-lang.org/en/learn/quickstart/hello_world/ :

# %%
# %%writefile hello.f90
# program main
#   ! This is a comment line; it is ignored by the compiler
#   print *, 'Hello, World!'
# end
# Out:
# Overwriting hello.f90

# %%
! flang-new hello.f90 -o hello

# %%
! ./hello
# Out:
#  Hello, World!

# %%
! wc -c hello
# Out:
# 738624 hello

# %%
! ls -lh hello
# Out:
# -rwx------. 1 u0_a124 u0_a124 722K Jun  6 21:54 hello

# %%
# %%bash
# flang-new hello.f90 -o hello

# %%
      -Wl,--no-eh-frame-hdr,--no-gnu-unique,--omagic,--nmagic,--no-relax \

# %%
# %%bash
# flang hello.f90 -o hello \
#     -O3 -g0 -DNDEBUG -flto\
#     -Wl,--gc-sections,--strip-all,--strip-debug \
#     -Wl,--hash-style=sysv,--build-id=none \
#     -Wl,--no-eh-frame-hdr,--no-gnu-unique,--no-relax \
#     -Wl,-z,norelro,-z,noseparate-code,-z,max-page-size=1,-z,common-page-size=1
# strip --strip-all --strip-debug --strip-unneeded \
#     -R .comment \
#     -R .note.android.ident \
#     -R .eh_frame \
#     hello

# %%
! ./hello
# Out:
#  Hello, World!

# %%
! wc -c hello
# Out:
# 113488 hello

# %%
! size hello
# Out:
#    text	   data	    bss	    dec	    hex	filename
#   93744	   1448	    160	  95352	  17478	hello

# %%
! ls -lh hello
# Out:
# -rwx------. 1 u0_a124 u0_a124 111K Jun  6 22:38 hello

# %%
! objdump -h hello
# Out:
# hello:	file format elf64-littleaarch64
#
# Sections:
# Idx Name           Size     VMA              Type
#   0                00000000 0000000000000000
#   1 .interp        00000015 00000000000001c8 DATA
#   2 .dynsym        00000468 0000000000000278 DATA
#   3 .gnu.version   0000005e 00000000000006e0 DATA
#   4 .gnu.version_r 00000040 0000000000000740 DATA
#   5 .hash          00000180 0000000000000780 DATA
#   6 .dynstr        000001f4 0000000000000900 DATA
#   7 .rela.dyn      000006f0 0000000000000af8 DATA
#   8 .rela.plt      00000420 00000000000011e8 DATA
#   9 .rodata        00001b31 0000000000001610 DATA
#  10 .text          00013c80 000000000000709c TEXT
#  11 .plt           000002e0 000000000001ad20 TEXT
#  12 .data          00000070 000000000001b000 DATA
#  13 .data.rel.ro   000001c0 000000000001b070 DATA
#  14 .init_array    00000008 000000000001b230 DATA
#  15 .dynamic       000001a0 000000000001b238 DATA
#  16 .got           00000058 000000000001b3d8 DATA
#  17 .got.plt       00000178 000000000001b430 DATA
#  18 .bss           000000a0 000000000001b5a8 BSS
#  19 .shstrtab      000000a2 0000000000000000

# %% [markdown]
# ---

# %%
# %%writefile array.f90
# program main
#   implicit none
#   integer :: i, j, k, N=3
#   real :: a(3,3,3)=reshape([ .50, .73, .22, .29, .65, .41, .69, .25,  &
#     .76, .64, .60, .73, .93, .24, .63, .19, .73, .77, .93, .70, .29,  &
#     .53, .34, .20, .91, .02, .47 ], shape(a), order=[3,2,1])
#   write(*,"(*(xg0.2))") (((a(k,j,:)),new_line('a'),j=1,N),new_line('a'),k=1,N)
#   write(*,"(*(xg0.2))") ((a(k,:,:)),new_line('a'),k=1,N)
# end
# Out:
# Overwriting array.f90

# %%
# %%bash
# flang array.f90 \
#     -O3 -g0 -DNDEBUG -flto\
#     -Wl,--gc-sections,--strip-all,--strip-debug \
#     -Wl,--hash-style=sysv,--build-id=none \
#     -Wl,--no-eh-frame-hdr,--no-gnu-unique,--no-relax \
#     -Wl,-z,norelro,-z,noseparate-code
# strip --strip-all --strip-debug --strip-unneeded \
#     -R .comment \
#     -R .note.android.ident \
#     -R .eh_frame \
#     a.out

# %%
! ./a.out
# Out:
#  .50 .73 .22
#  .29 .65 .41
#  .69 .25 .76
#
#  .64 .60 .73
#  .93 .24 .63
#  .19 .73 .77
#
#  .93 .70 .29
#  .53 .34 .20
#  .91 .20E-1 .47
#
#
#  .50 .29 .69 .73 .65 .25 .22 .41 .76
#  .64 .93 .19 .60 .24 .73 .73 .63 .77
#  .93 .53 .91 .70 .34 .20E-1 .29 .20 .47

# %%
! size a.out
# Out:
#    text	   data	    bss	    dec	    hex	filename
#  197681	   1504	    160	 199345	  30ab1	a.out

# %%
# %%writefile exit.f90
# program main
#     call exit(42)
# end
# Out:
# Overwriting exit.f90

# %%
# %%bash
# flang exit.f90 \
#     -O3 -g0 -DNDEBUG -flto\
#     -Wl,--gc-sections,--strip-all,--strip-debug \
#     -Wl,--hash-style=sysv,--build-id=none \
#     -Wl,--no-eh-frame-hdr,--no-gnu-unique,--no-relax \
#     -Wl,-z,norelro,-z,noseparate-code
# strip --strip-all --strip-debug --strip-unneeded \
#     -R .comment \
#     -R .note.android.ident \
#     -R .eh_frame \
#     a.out

# %%
! ./a.out ; echo $?
# Out:
# 42

# %%
! wc -c a.out
# Out:
# 30072 a.out

# %%
! size a.out
# Out:
#    text	   data	    bss	    dec	    hex	filename
#   22832	   1024	    160	  24016	   5dd0	a.out

# %%
! stat -c "%s %n" a.out
# Out:
# 30072 a.out

# %%
! objdump -x a.out
# Out:
# a.out:	file format elf64-littleaarch64
# architecture: aarch64
# start address: 0x0000000000002fb4
#
# Program Header:
#     PHDR off    0x0000000000000040 vaddr 0x0000000000000040 paddr 0x0000000000000040 align 2**3
#          filesz 0x0000000000000188 memsz 0x0000000000000188 flags r--
#   INTERP off    0x00000000000001c8 vaddr 0x00000000000001c8 paddr 0x00000000000001c8 align 2**0
#          filesz 0x0000000000000015 memsz 0x0000000000000015 flags r--
#     LOAD off    0x0000000000000000 vaddr 0x0000000000000000 paddr 0x0000000000000000 align 2**14
#          filesz 0x0000000000006bd0 memsz 0x0000000000006bd0 flags r-x
#     LOAD off    0x0000000000006bd0 vaddr 0x000000000000abd0 paddr 0x000000000000abd0 align 2**14
#          filesz 0x0000000000000400 memsz 0x00000000000004a0 flags rw-
#  DYNAMIC off    0x0000000000006ca8 vaddr 0x000000000000aca8 paddr 0x000000000000aca8 align 2**3
#          filesz 0x00000000000001a0 memsz 0x00000000000001a0 flags rw-
#    STACK off    0x0000000000000000 vaddr 0x0000000000000000 paddr 0x0000000000000000 align 2**64
#          filesz 0x0000000000000000 memsz 0x0000000000000000 flags rw-
#     NOTE off    0x00000000000001e0 vaddr 0x00000000000001e0 paddr 0x00000000000001e0 align 2**2
#          filesz 0x0000000000000098 memsz 0x0000000000000098 flags r--
#
# Dynamic Section:
#   RUNPATH      /data/data/com.termux/files/usr/lib
#   NEEDED       libm.so
#   NEEDED       libdl.so
#   NEEDED       libc.so
#   FLAGS        0x0000000000000008
#   FLAGS_1      0x0000000008000001
#   DEBUG        0x0000000000000000
#   RELA         0x00000000000009a8
#   RELASZ       0x00000000000002b8
#   RELAENT      0x0000000000000018
#   RELACOUNT    0x000000000000001b
#   JMPREL       0x0000000000000c60
#   PLTRELSZ     0x0000000000000360
#   PLTGOT       0x000000000000ae98
#   PLTREL       0x0000000000000007
#   SYMTAB       0x0000000000000278
#   SYMENT       0x0000000000000018
#   STRTAB       0x00000000000007f0
#   STRSZ        0x00000000000001b5
#   HASH         0x00000000000006b0
#   INIT_ARRAY   0x000000000000ac40
#   INIT_ARRAYSZ 0x0000000000000008
#   VERSYM       0x0000000000000620
#   VERNEED      0x0000000000000670
#   VERNEEDNUM   0x0000000000000002
#
# Version References:
#   required from libm.so:
#     0x00050d63 0x00 03 LIBC
#   required from libc.so:
#     0x00050d63 0x00 02 LIBC
#
# Sections:
# Idx Name           Size     VMA              Type
#   0                00000000 0000000000000000
#   1 .interp        00000015 00000000000001c8 DATA
#   2 .dynsym        000003a8 0000000000000278 DATA
#   3 .gnu.version   0000004e 0000000000000620 DATA
#   4 .gnu.version_r 00000040 0000000000000670 DATA
#   5 .hash          00000140 00000000000006b0 DATA
#   6 .dynstr        000001b5 00000000000007f0 DATA
#   7 .rela.dyn      000002b8 00000000000009a8 DATA
#   8 .rela.plt      00000360 0000000000000c60 DATA
#   9 .rodata        00000fc8 0000000000000fc0 DATA
#  10 .text          000039b0 0000000000002fb4 TEXT
#  11 .plt           00000260 0000000000006970 TEXT
#  12 .data          00000070 000000000000abd0 DATA
#  13 .init_array    00000008 000000000000ac40 DATA
#  14 .data.rel.ro   00000060 000000000000ac48 DATA
#  15 .dynamic       000001a0 000000000000aca8 DATA
#  16 .got           00000050 000000000000ae48 DATA
#  17 .got.plt       00000138 000000000000ae98 DATA
#  18 .bss           000000a0 000000000000afd0 BSS
#  19 .shstrtab      000000a2 0000000000000000
#
# SYMBOL TABLE:

# %%
# !objdump -d a.out
# Out:
# a.out:	file format elf64-littleaarch64
#
# Disassembly of section .text:
#
# 0000000000002fb4 <.text>:
#     2fb4: d503249f     	bti	j
#     2fb8: d280001d     	mov	x29, #0x0               // =0
#     2fbc: d280001e     	mov	x30, #0x0               // =0
#     2fc0: 910003e0     	mov	x0, sp
#     2fc4: 14000001     	b	0x2fc8 <.text+0x14>
#     2fc8: d503233f     	paciasp
#     2fcc: d10103ff     	sub	sp, sp, #0x40
#     2fd0: a9037bfd     	stp	x29, x30, [sp, #0x30]
#     2fd4: 9100c3fd     	add	x29, sp, #0x30
#     2fd8: 90000048     	adrp	x8, 0xa000 <memmove@plt+0x3440>
#     2fdc: 90000049     	adrp	x9, 0xa000 <memmove@plt+0x3440>
#     2fe0: 6f00e400     	movi	v0.2d, #0000000000000000
#     2fe4: f9472508     	ldr	x8, [x8, #0xe48]
#     2fe8: f9472929     	ldr	x9, [x9, #0xe50]
#     2fec: cb080128     	sub	x8, x9, x8
#     2ff0: f100051f     	cmp	x8, #0x1
#     2ff4: ad0083e0     	stp	q0, q0, [sp, #0x10]
#     2ff8: 3d8003e0     	str	q0, [sp]
#     2ffc: 5400008b     	b.lt	0x300c <.text+0x58>
#     3000: f0000028     	adrp	x8, 0xa000 <memmove@plt+0x3440>
#     3004: 912f4108     	add	x8, x8, #0xbd0
#     3008: f9000be8     	str	x8, [sp, #0x10]
#     300c: f0000022     	adrp	x2, 0xa000 <memmove@plt+0x3440>
#     3010: 910003e3     	mov	x3, sp
#     3014: aa1f03e1     	mov	x1, xzr
#     3018: f9472c42     	ldr	x2, [x2, #0xe58]
#     301c: 94000e5d     	bl	0x6990 <__libc_init@plt>
#     3020: d503245f     	bti	c
#     3024: b4000060     	cbz	x0, 0x3030 <.text+0x7c>
#     3028: aa0003f0     	mov	x16, x0
#     302c: d61f0200     	br	x16
#     3030: d65f03c0     	ret
#     3034: d503245f     	bti	c
#     3038: aa0003e1     	mov	x1, x0
#     303c: 90000000     	adrp	x0, 0x3000 <.text+0x4c>
#     3040: 91008000     	add	x0, x0, #0x20
#     3044: f0000022     	adrp	x2, 0xa000 <memmove@plt+0x3440>
#     3048: 913f4042     	add	x2, x2, #0xfd0
#     304c: 14000e55     	b	0x69a0 <__cxa_atexit@plt>
#     3050: d503245f     	bti	c
#     3054: f0000023     	adrp	x3, 0xa000 <memmove@plt+0x3440>
#     3058: 913f4063     	add	x3, x3, #0xfd0
#     305c: 14000e55     	b	0x69b0 <__register_atfork@plt>
#     3060: d503233f     	paciasp
#     3064: a9be7bfd     	stp	x29, x30, [sp, #-0x20]!
#     3068: a9014ff4     	stp	x20, x19, [sp, #0x10]
#     306c: 910003fd     	mov	x29, sp
#     3070: f0000033     	adrp	x19, 0xa000 <memmove@plt+0x3440>
#     3074: f0000028     	adrp	x8, 0xa000 <memmove@plt+0x3440>
#     3078: f9472673     	ldr	x19, [x19, #0xe48]
#     307c: f9472908     	ldr	x8, [x8, #0xe50]
#     3080: eb130108     	subs	x8, x8, x19
#     3084: 54000100     	b.eq	0x30a4 <.text+0xf0>
#     3088: 9343fd08     	asr	x8, x8, #3
#     308c: 8b080e69     	add	x9, x19, x8, lsl #3
#     3090: d1000514     	sub	x20, x8, #0x1
#     3094: f85f8129     	ldur	x9, [x9, #-0x8]
#     3098: d63f0120     	blr	x9
#     309c: aa1403e8     	mov	x8, x20
#     30a0: b5ffff74     	cbnz	x20, 0x308c <.text+0xd8>
#     30a4: a9414ff4     	ldp	x20, x19, [sp, #0x10]
#     30a8: a8c27bfd     	ldp	x29, x30, [sp], #0x20
#     30ac: d50323bf     	autiasp
#     30b0: d65f03c0     	ret
#     30b4: a9bd7bfd     	stp	x29, x30, [sp, #-0x30]!
#     30b8: a90157f6     	stp	x22, x21, [sp, #0x10]
#     30bc: a9024ff4     	stp	x20, x19, [sp, #0x20]
#     30c0: 910003fd     	mov	x29, sp
#     30c4: 2a0003f6     	mov	w22, w0
#     30c8: f0000020     	adrp	x0, 0xa000 <memmove@plt+0x3440>
#     30cc: aa0303f3     	mov	x19, x3
#     30d0: f9473400     	ldr	x0, [x0, #0xe68]
#     30d4: aa0203f4     	mov	x20, x2
#     30d8: aa0103f5     	mov	x21, x1
#     30dc: 97ffffd6     	bl	0x3034 <.text+0x80>
#     30e0: f0000020     	adrp	x0, 0xa000 <memmove@plt+0x3440>
#     30e4: 2a1603e1     	mov	w1, w22
#     30e8: aa1503e2     	mov	x2, x21
#     30ec: f9473000     	ldr	x0, [x0, #0xe60]
#     30f0: aa1403e3     	mov	x3, x20
#     30f4: aa1303e4     	mov	x4, x19
#     30f8: 94000013     	bl	0x3144 <.text+0x190>
#     30fc: 528013e0     	mov	w0, #0x9f               // =159
#     3100: 94000e30     	bl	0x69c0 <feclearexcept@plt>
#     3104: 2a1f03e0     	mov	w0, wzr
#     3108: a9424ff4     	ldp	x20, x19, [sp, #0x20]
#     310c: a94157f6     	ldp	x22, x21, [sp, #0x10]
#     3110: a8c37bfd     	ldp	x29, x30, [sp], #0x30
#     3114: 14000e2f     	b	0x69d0 <fesetround@plt>
#     3118: a9bf7bfd     	stp	x29, x30, [sp, #-0x10]!
#     311c: 910003fd     	mov	x29, sp
#     3120: f0000022     	adrp	x2, 0xa000 <memmove@plt+0x3440>
#     3124: 91304042     	add	x2, x2, #0xc10
#     3128: 940004c4     	bl	0x4438 <.text+0x1484>
#     312c: 7100141f     	cmp	w0, #0x5
#     3130: 1a9f27e8     	cset	w8, lo
#     3134: 1a9f3009     	csel	w9, w0, wzr, lo
#     3138: aa088120     	orr	x0, x9, x8, lsl #32
#     313c: a8c17bfd     	ldp	x29, x30, [sp], #0x10
#     3140: d65f03c0     	ret
#     3144: d10183ff     	sub	sp, sp, #0x60
#     3148: a9027bfd     	stp	x29, x30, [sp, #0x20]
#     314c: f9001bf7     	str	x23, [sp, #0x30]
#     3150: a90457f6     	stp	x22, x21, [sp, #0x40]
#     3154: a9054ff4     	stp	x20, x19, [sp, #0x50]
#     3158: 910083fd     	add	x29, sp, #0x20
#     315c: d53bd055     	mrs	x21, TPIDR_EL0
#     3160: aa0003f3     	mov	x19, x0
#     3164: f94016a8     	ldr	x8, [x21, #0x28]
#     3168: f81f83a8     	stur	x8, [x29, #-0x8]
#     316c: b9000001     	str	w1, [x0]
#     3170: f9000402     	str	x2, [x0, #0x8]
#     3174: b4000264     	cbz	x4, 0x31c0 <.text+0x20c>
#     3178: b9400088     	ldr	w8, [x4]
#     317c: aa0403f4     	mov	x20, x4
#     3180: 7100051f     	cmp	w8, #0x1
#     3184: 540001eb     	b.lt	0x31c0 <.text+0x20c>
#     3188: aa1f03f6     	mov	x22, xzr
#     318c: aa1f03f7     	mov	x23, xzr
#     3190: f9400688     	ldr	x8, [x20, #0x8]
#     3194: 2a1f03e2     	mov	w2, wzr
#     3198: 8b160108     	add	x8, x8, x22
#     319c: a9400500     	ldp	x0, x1, [x8]
#     31a0: 94000e10     	bl	0x69e0 <setenv@plt>
#     31a4: 3100041f     	cmn	w0, #0x1
#     31a8: 540010e0     	b.eq	0x33c4 <.text+0x410>
#     31ac: b9800288     	ldrsw	x8, [x20]
#     31b0: 910006f7     	add	x23, x23, #0x1
#     31b4: 910042d6     	add	x22, x22, #0x10
#     31b8: eb0802ff     	cmp	x23, x8
#     31bc: 54fffeab     	b.lt	0x3190 <.text+0x1dc>
#     31c0: f0000028     	adrp	x8, 0xa000 <memmove@plt+0x3440>
#     31c4: b0ffffe9     	adrp	x9, 0x0
#     31c8: d0ffffe0     	adrp	x0, 0x1000
#     31cc: 91331000     	add	x0, x0, #0xcc4
#     31d0: f9473908     	ldr	x8, [x8, #0xe70]
#     31d4: fd47e120     	ldr	d0, [x9, #0xfc0]
#     31d8: b900227f     	str	wzr, [x19, #0x20]
#     31dc: f9400108     	ldr	x8, [x8]
#     31e0: fd000e60     	str	d0, [x19, #0x18]
#     31e4: f9000a68     	str	x8, [x19, #0x10]
#     31e8: 94000e02     	bl	0x69f0 <getenv@plt>
#     31ec: b40001c0     	cbz	x0, 0x3224 <.text+0x270>
#     31f0: 910023e1     	add	x1, sp, #0x8
#     31f4: 52800142     	mov	w2, #0xa                // =10
#     31f8: aa0003f4     	mov	x20, x0
#     31fc: 94000e01     	bl	0x6a00 <strtol@plt>
#     3200: 529fffa8     	mov	w8, #0xfffd             // =65533
#     3204: d1000409     	sub	x9, x0, #0x1
#     3208: 72afffe8     	movk	w8, #0x7fff, lsl #16
#     320c: eb08013f     	cmp	x9, x8
#     3210: 540008a8     	b.hi	0x3324 <.text+0x370>
#     3214: f94007e8     	ldr	x8, [sp, #0x8]
#     3218: 39400108     	ldrb	w8, [x8]
#     321c: 35000848     	cbnz	w8, 0x3324 <.text+0x370>
#     3220: b9001a60     	str	w0, [x19, #0x18]
#     3224: d0ffffe0     	adrp	x0, 0x1000
#     3228: 910d0400     	add	x0, x0, #0x341
#     322c: 94000df1     	bl	0x69f0 <getenv@plt>
#     3230: b4000120     	cbz	x0, 0x3254 <.text+0x2a0>
#     3234: aa0003f4     	mov	x20, x0
#     3238: 94000df6     	bl	0x6a10 <strlen@plt>
#     323c: aa0003e1     	mov	x1, x0
#     3240: aa1403e0     	mov	x0, x20
#     3244: 97ffffb5     	bl	0x3118 <.text+0x164>
#     3248: f2601c1f     	tst	x0, #0xff00000000
#     324c: 54000ac0     	b.eq	0x33a4 <.text+0x3f0>
#     3250: b9002260     	str	w0, [x19, #0x20]
#     3254: d0ffffe0     	adrp	x0, 0x1000
#     3258: 910f3800     	add	x0, x0, #0x3ce
#     325c: 94000de5     	bl	0x69f0 <getenv@plt>
#     3260: b4000160     	cbz	x0, 0x328c <.text+0x2d8>
#     3264: 910023e1     	add	x1, sp, #0x8
#     3268: 52800142     	mov	w2, #0xa                // =10
#     326c: aa0003f4     	mov	x20, x0
#     3270: 94000de4     	bl	0x6a00 <strtol@plt>
#     3274: f100041f     	cmp	x0, #0x1
#     3278: 54000668     	b.hi	0x3344 <.text+0x390>
#     327c: f94007e8     	ldr	x8, [sp, #0x8]
#     3280: 39400108     	ldrb	w8, [x8]
#     3284: 35000608     	cbnz	w8, 0x3344 <.text+0x390>
#     3288: 39009260     	strb	w0, [x19, #0x24]
#     328c: d0ffffe0     	adrp	x0, 0x1000
#     3290: 912b0800     	add	x0, x0, #0xac2
#     3294: 94000dd7     	bl	0x69f0 <getenv@plt>
#     3298: b4000160     	cbz	x0, 0x32c4 <.text+0x310>
#     329c: 910023e1     	add	x1, sp, #0x8
#     32a0: 52800142     	mov	w2, #0xa                // =10
#     32a4: aa0003f4     	mov	x20, x0
#     32a8: 94000dd6     	bl	0x6a00 <strtol@plt>
#     32ac: f100041f     	cmp	x0, #0x1
#     32b0: 540005a8     	b.hi	0x3364 <.text+0x3b0>
#     32b4: f94007e8     	ldr	x8, [sp, #0x8]
#     32b8: 39400108     	ldrb	w8, [x8]
#     32bc: 35000548     	cbnz	w8, 0x3364 <.text+0x3b0>
#     32c0: 39009660     	strb	w0, [x19, #0x25]
#     32c4: d0ffffe0     	adrp	x0, 0x1000
#     32c8: 91158400     	add	x0, x0, #0x561
#     32cc: 94000dc9     	bl	0x69f0 <getenv@plt>
#     32d0: b4000160     	cbz	x0, 0x32fc <.text+0x348>
#     32d4: 910023e1     	add	x1, sp, #0x8
#     32d8: 52800142     	mov	w2, #0xa                // =10
#     32dc: aa0003f4     	mov	x20, x0
#     32e0: 94000dc8     	bl	0x6a00 <strtol@plt>
#     32e4: f100041f     	cmp	x0, #0x1
#     32e8: 540004e8     	b.hi	0x3384 <.text+0x3d0>
#     32ec: f94007e8     	ldr	x8, [sp, #0x8]
#     32f0: 39400108     	ldrb	w8, [x8]
#     32f4: 35000488     	cbnz	w8, 0x3384 <.text+0x3d0>
#     32f8: 39009a60     	strb	w0, [x19, #0x26]
#     32fc: f94016a8     	ldr	x8, [x21, #0x28]
#     3300: f85f83a9     	ldur	x9, [x29, #-0x8]
#     3304: eb09011f     	cmp	x8, x9
#     3308: 54000741     	b.ne	0x33f0 <.text+0x43c>
#     330c: a9454ff4     	ldp	x20, x19, [sp, #0x50]
#     3310: f9401bf7     	ldr	x23, [sp, #0x30]
#     3314: a94457f6     	ldp	x22, x21, [sp, #0x40]
#     3318: a9427bfd     	ldp	x29, x30, [sp, #0x20]
#     331c: 910183ff     	add	sp, sp, #0x60
#     3320: d65f03c0     	ret
#     3324: f0000028     	adrp	x8, 0xa000 <memmove@plt+0x3440>
#     3328: d0ffffe1     	adrp	x1, 0x1000
#     332c: 91357c21     	add	x1, x1, #0xd5f
#     3330: f9473d08     	ldr	x8, [x8, #0xe78]
#     3334: aa1403e2     	mov	x2, x20
#     3338: f9400100     	ldr	x0, [x8]
#     333c: 94000db9     	bl	0x6a20 <fprintf@plt>
#     3340: 17ffffb9     	b	0x3224 <.text+0x270>
#     3344: f0000028     	adrp	x8, 0xa000 <memmove@plt+0x3440>
#     3348: d0ffffe1     	adrp	x1, 0x1000
#     334c: 91365821     	add	x1, x1, #0xd96
#     3350: f9473d08     	ldr	x8, [x8, #0xe78]
#     3354: aa1403e2     	mov	x2, x20
#     3358: f9400100     	ldr	x0, [x8]
#     335c: 94000db1     	bl	0x6a20 <fprintf@plt>
#     3360: 17ffffcb     	b	0x328c <.text+0x2d8>
#     3364: f0000028     	adrp	x8, 0xa000 <memmove@plt+0x3440>
#     3368: b0ffffe1     	adrp	x1, 0x0
#     336c: 913f2021     	add	x1, x1, #0xfc8
#     3370: f9473d08     	ldr	x8, [x8, #0xe78]
#     3374: aa1403e2     	mov	x2, x20
#     3378: f9400100     	ldr	x0, [x8]
#     337c: 94000da9     	bl	0x6a20 <fprintf@plt>
#     3380: 17ffffd1     	b	0x32c4 <.text+0x310>
#     3384: f0000028     	adrp	x8, 0xa000 <memmove@plt+0x3440>
#     3388: d0ffffe1     	adrp	x1, 0x1000
#     338c: 91334821     	add	x1, x1, #0xcd2
#     3390: f9473d08     	ldr	x8, [x8, #0xe78]
#     3394: aa1403e2     	mov	x2, x20
#     3398: f9400100     	ldr	x0, [x8]
#     339c: 94000da1     	bl	0x6a20 <fprintf@plt>
#     33a0: 17ffffd7     	b	0x32fc <.text+0x348>
#     33a4: f0000028     	adrp	x8, 0xa000 <memmove@plt+0x3440>
#     33a8: d0ffffe1     	adrp	x1, 0x1000
#     33ac: 9128d021     	add	x1, x1, #0xa34
#     33b0: f9473d08     	ldr	x8, [x8, #0xe78]
#     33b4: aa1403e2     	mov	x2, x20
#     33b8: f9400100     	ldr	x0, [x8]
#     33bc: 94000d99     	bl	0x6a20 <fprintf@plt>
#     33c0: 17ffffa5     	b	0x3254 <.text+0x2a0>
#     33c4: d0ffffe8     	adrp	x8, 0x1000
#     33c8: 9104a908     	add	x8, x8, #0x12a
#     33cc: f90007e8     	str	x8, [sp, #0x8]
#     33d0: 52800608     	mov	w8, #0x30               // =48
#     33d4: b90013e8     	str	w8, [sp, #0x10]
#     33d8: 94000d96     	bl	0x6a30 <__errno@plt>
#     33dc: b9400000     	ldr	w0, [x0]
#     33e0: 94000d98     	bl	0x6a40 <strerror@plt>
#     33e4: aa0003e1     	mov	x1, x0
#     33e8: 910023e0     	add	x0, sp, #0x8
#     33ec: 94000002     	bl	0x33f4 <.text+0x440>
#     33f0: 94000d98     	bl	0x6a50 <__stack_chk_fail@plt>
#     33f4: a9be7bfd     	stp	x29, x30, [sp, #-0x20]!
#     33f8: a9014ff4     	stp	x20, x19, [sp, #0x10]
#     33fc: 910003fd     	mov	x29, sp
#     3400: aa0103f3     	mov	x19, x1
#     3404: aa0003f4     	mov	x20, x0
#     3408: 9400036b     	bl	0x41b4 <.text+0x1200>
#     340c: aa1403e0     	mov	x0, x20
#     3410: 940003a6     	bl	0x42a8 <.text+0x12f4>
#     3414: aa1403e0     	mov	x0, x20
#     3418: aa1303e1     	mov	x1, x19
#     341c: 94000003     	bl	0x3428 <.text+0x474>
#     3420: aa1403e0     	mov	x0, x20
#     3424: 940003c0     	bl	0x4324 <.text+0x1370>
#     3428: f0000028     	adrp	x8, 0xa000 <memmove@plt+0x3440>
#     342c: f9473d08     	ldr	x8, [x8, #0xe78]
#     3430: f9400100     	ldr	x0, [x8]
#     3434: 14000d7b     	b	0x6a20 <fprintf@plt>
#     3438: a9be7bfd     	stp	x29, x30, [sp, #-0x20]!
#     343c: a9014ff4     	stp	x20, x19, [sp, #0x10]
#     3440: 910003fd     	mov	x29, sp
#     3444: aa0003f4     	mov	x20, x0
#     3448: aa0103e0     	mov	x0, x1
#     344c: aa0103f3     	mov	x19, x1
#     3450: 94000d84     	bl	0x6a60 <malloc@plt>
#     3454: b5000040     	cbnz	x0, 0x345c <.text+0x4a8>
#     3458: b5000093     	cbnz	x19, 0x3468 <.text+0x4b4>
#     345c: a9414ff4     	ldp	x20, x19, [sp, #0x10]
#     3460: a8c27bfd     	ldp	x29, x30, [sp], #0x20
#     3464: d65f03c0     	ret
#     3468: d0ffffe1     	adrp	x1, 0x1000
#     346c: 912c4821     	add	x1, x1, #0xb12
#     3470: aa1403e0     	mov	x0, x20
#     3474: aa1303e2     	mov	x2, x19
#     3478: 94000001     	bl	0x347c <.text+0x4c8>
#     347c: a9bd7bfd     	stp	x29, x30, [sp, #-0x30]!
#     3480: f9000bf5     	str	x21, [sp, #0x10]
#     3484: a9024ff4     	stp	x20, x19, [sp, #0x20]
#     3488: 910003fd     	mov	x29, sp
#     348c: aa0203f3     	mov	x19, x2
#     3490: aa0103f4     	mov	x20, x1
#     3494: aa0003f5     	mov	x21, x0
#     3498: 94000347     	bl	0x41b4 <.text+0x1200>
#     349c: aa1503e0     	mov	x0, x21
#     34a0: 94000382     	bl	0x42a8 <.text+0x12f4>
#     34a4: aa1503e0     	mov	x0, x21
#     34a8: aa1403e1     	mov	x1, x20
#     34ac: aa1303e2     	mov	x2, x19
#     34b0: 94000004     	bl	0x34c0 <.text+0x50c>
#     34b4: aa1503e0     	mov	x0, x21
#     34b8: 9400039b     	bl	0x4324 <.text+0x1370>
#     34bc: 14000d6d     	b	0x6a70 <free@plt>
#     34c0: f0000028     	adrp	x8, 0xa000 <memmove@plt+0x3440>
#     34c4: f9473d08     	ldr	x8, [x8, #0xe78]
#     34c8: f9400100     	ldr	x0, [x8]
#     34cc: 14000d55     	b	0x6a20 <fprintf@plt>
#     34d0: d10143ff     	sub	sp, sp, #0x50
#     34d4: a9037bfd     	stp	x29, x30, [sp, #0x30]
#     34d8: f90023f3     	str	x19, [sp, #0x40]
#     34dc: 9100c3fd     	add	x29, sp, #0x30
#     34e0: d53bd053     	mrs	x19, TPIDR_EL0
#     34e4: f9401668     	ldr	x8, [x19, #0x28]
#     34e8: f81f83a8     	stur	x8, [x29, #-0x8]
#     34ec: f90003e0     	str	x0, [sp]
#     34f0: 910003e0     	mov	x0, sp
#     34f4: b9000bff     	str	wzr, [sp, #0x8]
#     34f8: 390033ff     	strb	wzr, [sp, #0xc]
#     34fc: b90013ff     	str	wzr, [sp, #0x10]
#     3500: f9000fff     	str	xzr, [sp, #0x18]
#     3504: b90023ff     	str	wzr, [sp, #0x20]
#     3508: 9400007d     	bl	0x36fc <.text+0x748>
#     350c: f9400fe0     	ldr	x0, [sp, #0x18]
#     3510: b4000040     	cbz	x0, 0x3518 <.text+0x564>
#     3514: 97ffffea     	bl	0x34bc <.text+0x508>
#     3518: f9401668     	ldr	x8, [x19, #0x28]
#     351c: f85f83a9     	ldur	x9, [x29, #-0x8]
#     3520: eb09011f     	cmp	x8, x9
#     3524: 540000a1     	b.ne	0x3538 <.text+0x584>
#     3528: a9437bfd     	ldp	x29, x30, [sp, #0x30]
#     352c: f94023f3     	ldr	x19, [sp, #0x40]
#     3530: 910143ff     	add	sp, sp, #0x50
#     3534: d65f03c0     	ret
#     3538: 94000d46     	bl	0x6a50 <__stack_chk_fail@plt>
#     353c: a9bf7bfd     	stp	x29, x30, [sp, #-0x10]!
#     3540: 910003fd     	mov	x29, sp
#     3544: d0ffffe0     	adrp	x0, 0x1000
#     3548: 910bc800     	add	x0, x0, #0x2f2
#     354c: 97ffffe1     	bl	0x34d0 <.text+0x51c>
#     3550: 2a1f03e0     	mov	w0, wzr
#     3554: 94000d4f     	bl	0x6a90 <exit@plt>
#     3558: a9be7bfd     	stp	x29, x30, [sp, #-0x20]!
#     355c: f9000bf3     	str	x19, [sp, #0x10]
#     3560: 910003fd     	mov	x29, sp
#     3564: 2a0003f3     	mov	w19, w0
#     3568: d0ffffe0     	adrp	x0, 0x1000
#     356c: 91225800     	add	x0, x0, #0x896
#     3570: 97ffffd8     	bl	0x34d0 <.text+0x51c>
#     3574: 2a1303e0     	mov	w0, w19
#     3578: 94000d46     	bl	0x6a90 <exit@plt>
#     357c: 14000d51     	b	0x6ac0 <pthread_mutex_destroy@plt>
#     3580: d10183ff     	sub	sp, sp, #0x60
#     3584: a9037bfd     	stp	x29, x30, [sp, #0x30]
#     3588: a90457f6     	stp	x22, x21, [sp, #0x40]
#     358c: a9054ff4     	stp	x20, x19, [sp, #0x50]
#     3590: 9100c3fd     	add	x29, sp, #0x30
#     3594: d53bd054     	mrs	x20, TPIDR_EL0
#     3598: f0000036     	adrp	x22, 0xa000 <memmove@plt+0x3440>
#     359c: f0000035     	adrp	x21, 0xa000 <memmove@plt+0x3440>
#     35a0: f9401688     	ldr	x8, [x20, #0x28]
#     35a4: f94742d6     	ldr	x22, [x22, #0xe80]
#     35a8: f94746b5     	ldr	x21, [x21, #0xe88]
#     35ac: f81f83a8     	stur	x8, [x29, #-0x8]
#     35b0: f94002c8     	ldr	x8, [x22]
#     35b4: f94002a9     	ldr	x9, [x21]
#     35b8: aa090108     	orr	x8, x8, x9
#     35bc: b4000348     	cbz	x8, 0x3624 <.text+0x670>
#     35c0: 3dc00000     	ldr	q0, [x0]
#     35c4: f0000033     	adrp	x19, 0xa000 <memmove@plt+0x3440>
#     35c8: 913f6273     	add	x19, x19, #0xfd8
#     35cc: 52800028     	mov	w8, #0x1                // =1
#     35d0: aa1303e0     	mov	x0, x19
#     35d4: b90013ff     	str	wzr, [sp, #0x10]
#     35d8: f9000fff     	str	xzr, [sp, #0x18]
#     35dc: 3d8003e0     	str	q0, [sp]
#     35e0: b90023ff     	str	wzr, [sp, #0x20]
#     35e4: 390033e8     	strb	w8, [sp, #0xc]
#     35e8: 94000065     	bl	0x377c <.text+0x7c8>
#     35ec: f94002c0     	ldr	x0, [x22]
#     35f0: b4000060     	cbz	x0, 0x35fc <.text+0x648>
#     35f4: 910003e1     	mov	x1, sp
#     35f8: 94000763     	bl	0x5384 <.text+0x23d0>
#     35fc: f94002a0     	ldr	x0, [x21]
#     3600: b4000060     	cbz	x0, 0x360c <.text+0x658>
#     3604: 910003e1     	mov	x1, sp
#     3608: 9400075f     	bl	0x5384 <.text+0x23d0>
#     360c: aa1303e0     	mov	x0, x19
#     3610: 3900a27f     	strb	wzr, [x19, #0x28]
#     3614: 94000d2f     	bl	0x6ad0 <pthread_mutex_unlock@plt>
#     3618: f9400fe0     	ldr	x0, [sp, #0x18]
#     361c: b4000040     	cbz	x0, 0x3624 <.text+0x670>
#     3620: 97ffffa7     	bl	0x34bc <.text+0x508>
#     3624: f9401688     	ldr	x8, [x20, #0x28]
#     3628: f85f83a9     	ldur	x9, [x29, #-0x8]
#     362c: eb09011f     	cmp	x8, x9
#     3630: 540000c1     	b.ne	0x3648 <.text+0x694>
#     3634: a9454ff4     	ldp	x20, x19, [sp, #0x50]
#     3638: a94457f6     	ldp	x22, x21, [sp, #0x40]
#     363c: a9437bfd     	ldp	x29, x30, [sp, #0x30]
#     3640: 910183ff     	add	sp, sp, #0x60
#     3644: d65f03c0     	ret
#     3648: 94000d02     	bl	0x6a50 <__stack_chk_fail@plt>
#     364c: 3940c008     	ldrb	w8, [x0, #0x30]
#     3650: 350001c8     	cbnz	w8, 0x3688 <.text+0x6d4>
#     3654: f9400809     	ldr	x9, [x0, #0x10]
#     3658: eb090028     	subs	x8, x1, x9
#     365c: 540000ed     	b.le	0x3678 <.text+0x6c4>
#     3660: f940100a     	ldr	x10, [x0, #0x20]
#     3664: 8b090149     	add	x9, x10, x9
#     3668: eb01013f     	cmp	x9, x1
#     366c: 5400004d     	b.le	0x3674 <.text+0x6c0>
#     3670: f9001008     	str	x8, [x0, #0x20]
#     3674: d65f03c0     	ret
#     3678: a9027c1f     	stp	xzr, xzr, [x0, #0x20]
#     367c: a9017c01     	stp	x1, xzr, [x0, #0x10]
#     3680: 3900c01f     	strb	wzr, [x0, #0x30]
#     3684: d65f03c0     	ret
#     3688: a9bf7bfd     	stp	x29, x30, [sp, #-0x10]!
#     368c: 910003fd     	mov	x29, sp
#     3690: d0ffffe8     	adrp	x8, 0x1000
#     3694: 913bbd08     	add	x8, x8, #0xeef
#     3698: d0ffffe1     	adrp	x1, 0x1000
#     369c: 910d3821     	add	x1, x1, #0x34e
#     36a0: aa0203e0     	mov	x0, x2
#     36a4: aa0803e2     	mov	x2, x8
#     36a8: 52801123     	mov	w3, #0x89               // =137
#     36ac: 9400032a     	bl	0x4354 <.text+0x13a0>
#     36b0: a9bd7bfd     	stp	x29, x30, [sp, #-0x30]!
#     36b4: f9000bf5     	str	x21, [sp, #0x10]
#     36b8: a9024ff4     	stp	x20, x19, [sp, #0x20]
#     36bc: 910003fd     	mov	x29, sp
#     36c0: 2a0103f4     	mov	w20, w1
#     36c4: aa0203e1     	mov	x1, x2
#     36c8: aa0203f3     	mov	x19, x2
#     36cc: aa0003f5     	mov	x21, x0
#     36d0: 94000aea     	bl	0x6278 <.text+0x32c4>
#     36d4: aa1503e0     	mov	x0, x21
#     36d8: aa1303e1     	mov	x1, x19
#     36dc: 9400072a     	bl	0x5384 <.text+0x23d0>
#     36e0: 9101e2a0     	add	x0, x21, #0x78
#     36e4: 2a1403e1     	mov	w1, w20
#     36e8: aa1303e2     	mov	x2, x19
#     36ec: a9424ff4     	ldp	x20, x19, [sp, #0x20]
#     36f0: f9400bf5     	ldr	x21, [sp, #0x10]
#     36f4: a8c37bfd     	ldp	x29, x30, [sp], #0x30
#     36f8: 140001c3     	b	0x3e04 <.text+0xe50>
#     36fc: a9bd7bfd     	stp	x29, x30, [sp, #-0x30]!
#     3700: f9000bf5     	str	x21, [sp, #0x10]
#     3704: a9024ff4     	stp	x20, x19, [sp, #0x20]
#     3708: 910003fd     	mov	x29, sp
#     370c: f0000033     	adrp	x19, 0xa000 <memmove@plt+0x3440>
#     3710: 913f6273     	add	x19, x19, #0xfd8
#     3714: aa0003f4     	mov	x20, x0
#     3718: aa1303e0     	mov	x0, x19
#     371c: 94000018     	bl	0x377c <.text+0x7c8>
#     3720: 90000055     	adrp	x21, 0xb000
#     3724: f94026a0     	ldr	x0, [x21, #0x48]
#     3728: b40000c0     	cbz	x0, 0x3740 <.text+0x78c>
#     372c: aa1403e1     	mov	x1, x20
#     3730: 9400039d     	bl	0x45a4 <.text+0x15f0>
#     3734: f94026a0     	ldr	x0, [x21, #0x48]
#     3738: 97ffff61     	bl	0x34bc <.text+0x508>
#     373c: f90026bf     	str	xzr, [x21, #0x48]
#     3740: f0000028     	adrp	x8, 0xa000 <memmove@plt+0x3440>
#     3744: f0000029     	adrp	x9, 0xa000 <memmove@plt+0x3440>
#     3748: f000002a     	adrp	x10, 0xa000 <memmove@plt+0x3440>
#     374c: f9474108     	ldr	x8, [x8, #0xe80]
#     3750: f9474929     	ldr	x9, [x9, #0xe90]
#     3754: f947454a     	ldr	x10, [x10, #0xe88]
#     3758: aa1303e0     	mov	x0, x19
#     375c: f900011f     	str	xzr, [x8]
#     3760: f900013f     	str	xzr, [x9]
#     3764: f900015f     	str	xzr, [x10]
#     3768: 3900a27f     	strb	wzr, [x19, #0x28]
#     376c: a9424ff4     	ldp	x20, x19, [sp, #0x20]
#     3770: f9400bf5     	ldr	x21, [sp, #0x10]
#     3774: a8c37bfd     	ldp	x29, x30, [sp], #0x30
#     3778: 14000cd6     	b	0x6ad0 <pthread_mutex_unlock@plt>
#     377c: a9be7bfd     	stp	x29, x30, [sp, #-0x20]!
#     3780: f9000bf3     	str	x19, [sp, #0x10]
#     3784: 910003fd     	mov	x29, sp
#     3788: aa0003f3     	mov	x19, x0
#     378c: aa1303e0     	mov	x0, x19
#     3790: 94000cdc     	bl	0x6b00 <pthread_mutex_lock@plt>
#     3794: 35ffffc0     	cbnz	w0, 0x378c <.text+0x7d8>
#     3798: 94000cde     	bl	0x6b10 <pthread_self@plt>
#     379c: 52800028     	mov	w8, #0x1                // =1
#     37a0: f9001a60     	str	x0, [x19, #0x30]
#     37a4: 3900a268     	strb	w8, [x19, #0x28]
#     37a8: f9400bf3     	ldr	x19, [sp, #0x10]
#     37ac: a8c27bfd     	ldp	x29, x30, [sp], #0x20
#     37b0: d65f03c0     	ret
#     37b4: a9bd7bfd     	stp	x29, x30, [sp, #-0x30]!
#     37b8: f9000bf5     	str	x21, [sp, #0x10]
#     37bc: a9024ff4     	stp	x20, x19, [sp, #0x20]
#     37c0: 910003fd     	mov	x29, sp
#     37c4: 6f00e400     	movi	v0.2d, #0000000000000000
#     37c8: f0000033     	adrp	x19, 0xa000 <memmove@plt+0x3440>
#     37cc: 913f6273     	add	x19, x19, #0xfd8
#     37d0: aa1303e0     	mov	x0, x19
#     37d4: aa1f03e1     	mov	x1, xzr
#     37d8: f900127f     	str	xzr, [x19, #0x20]
#     37dc: ad000260     	stp	q0, q0, [x19]
#     37e0: 3900a27f     	strb	wzr, [x19, #0x28]
#     37e4: 94000cc3     	bl	0x6af0 <pthread_mutex_init@plt>
#     37e8: 90000014     	adrp	x20, 0x3000 <.text+0x4c>
#     37ec: 9115f294     	add	x20, x20, #0x57c
#     37f0: f0000035     	adrp	x21, 0xa000 <memmove@plt+0x3440>
#     37f4: 913f42b5     	add	x21, x21, #0xfd0
#     37f8: aa1403e0     	mov	x0, x20
#     37fc: aa1303e1     	mov	x1, x19
#     3800: aa1503e2     	mov	x2, x21
#     3804: 94000c67     	bl	0x69a0 <__cxa_atexit@plt>
#     3808: 6f00e400     	movi	v0.2d, #0000000000000000
#     380c: 90000053     	adrp	x19, 0xb000
#     3810: 91004273     	add	x19, x19, #0x10
#     3814: aa1303e0     	mov	x0, x19
#     3818: aa1f03e1     	mov	x1, xzr
#     381c: f900127f     	str	xzr, [x19, #0x20]
#     3820: ad000260     	stp	q0, q0, [x19]
#     3824: 3900a27f     	strb	wzr, [x19, #0x28]
#     3828: 94000cb2     	bl	0x6af0 <pthread_mutex_init@plt>
#     382c: aa1403e0     	mov	x0, x20
#     3830: aa1303e1     	mov	x1, x19
#     3834: aa1503e2     	mov	x2, x21
#     3838: a9424ff4     	ldp	x20, x19, [sp, #0x20]
#     383c: f9400bf5     	ldr	x21, [sp, #0x10]
#     3840: a8c37bfd     	ldp	x29, x30, [sp], #0x30
#     3844: 14000c57     	b	0x69a0 <__cxa_atexit@plt>
#     3848: a9bd7bfd     	stp	x29, x30, [sp, #-0x30]!
#     384c: a90157fc     	stp	x28, x21, [sp, #0x10]
#     3850: a9024ff4     	stp	x20, x19, [sp, #0x20]
#     3854: 910003fd     	mov	x29, sp
#     3858: d10843ff     	sub	sp, sp, #0x210
#     385c: a90913e3     	stp	x3, x4, [sp, #0x90]
#     3860: aa0203e8     	mov	x8, x2
#     3864: aa0003f3     	mov	x19, x0
#     3868: a90a1be5     	stp	x5, x6, [sp, #0xa0]
#     386c: f9005be7     	str	x7, [sp, #0xb0]
#     3870: ad0087e0     	stp	q0, q1, [sp, #0x10]
#     3874: ad018fe2     	stp	q2, q3, [sp, #0x30]
#     3878: ad0297e4     	stp	q4, q5, [sp, #0x50]
#     387c: ad039fe6     	stp	q6, q7, [sp, #0x70]
#     3880: d53bd054     	mrs	x20, TPIDR_EL0
#     3884: f9401689     	ldr	x9, [x20, #0x28]
#     3888: 3100083f     	cmn	w1, #0x2
#     388c: f81f83a9     	stur	x9, [x29, #-0x8]
#     3890: 54000220     	b.eq	0x38d4 <.text+0x920>
#     3894: 34000421     	cbz	w1, 0x3918 <.text+0x964>
#     3898: 3100043f     	cmn	w1, #0x1
#     389c: 54000321     	b.ne	0x3900 <.text+0x94c>
#     38a0: 39403269     	ldrb	w9, [x19, #0xc]
#     38a4: 528000aa     	mov	w10, #0x5               // =5
#     38a8: 6a0a013f     	tst	w9, w10
#     38ac: 54000081     	b.ne	0x38bc <.text+0x908>
#     38b0: 1203e129     	and	w9, w9, #0x22222222
#     38b4: 7100893f     	cmp	w9, #0x22
#     38b8: 54000961     	b.ne	0x39e4 <.text+0xa30>
#     38bc: b9401268     	ldr	w8, [x19, #0x10]
#     38c0: 34000068     	cbz	w8, 0x38cc <.text+0x918>
#     38c4: 3100091f     	cmn	w8, #0x2
#     38c8: 5400028c     	b.gt	0x3918 <.text+0x964>
#     38cc: 12800008     	mov	w8, #-0x1               // =-1
#     38d0: 1400000a     	b	0x38f8 <.text+0x944>
#     38d4: 39403269     	ldrb	w9, [x19, #0xc]
#     38d8: 5280012a     	mov	w10, #0x9               // =9
#     38dc: 6a0a013f     	tst	w9, w10
#     38e0: 54000820     	b.eq	0x39e4 <.text+0xa30>
#     38e4: b9401268     	ldr	w8, [x19, #0x10]
#     38e8: 34000068     	cbz	w8, 0x38f4 <.text+0x940>
#     38ec: 31000d1f     	cmn	w8, #0x3
#     38f0: 5400014c     	b.gt	0x3918 <.text+0x964>
#     38f4: 12800028     	mov	w8, #-0x2               // =-2
#     38f8: b9001268     	str	w8, [x19, #0x10]
#     38fc: 14000007     	b	0x3918 <.text+0x964>
#     3900: 39403269     	ldrb	w9, [x19, #0xc]
#     3904: 7200053f     	tst	w9, #0x3
#     3908: 540006e0     	b.eq	0x39e4 <.text+0xa30>
#     390c: b940126a     	ldr	w10, [x19, #0x10]
#     3910: 7100015f     	cmp	w10, #0x0
#     3914: 5400014d     	b.le	0x393c <.text+0x988>
#     3918: f9401688     	ldr	x8, [x20, #0x28]
#     391c: f85f83a9     	ldur	x9, [x29, #-0x8]
#     3920: eb09011f     	cmp	x8, x9
#     3924: 540005e1     	b.ne	0x39e0 <.text+0xa2c>
#     3928: 910843ff     	add	sp, sp, #0x210
#     392c: a9424ff4     	ldp	x20, x19, [sp, #0x20]
#     3930: a94157fc     	ldp	x28, x21, [sp, #0x10]
#     3934: a8c37bfd     	ldp	x29, x30, [sp], #0x30
#     3938: d65f03c0     	ret
#     393c: b9001261     	str	w1, [x19, #0x10]
#     3940: b4fffec8     	cbz	x8, 0x3918 <.text+0x964>
#     3944: 3627fea9     	tbz	w9, #0x4, 0x3918 <.text+0x964>
#     3948: 928004e9     	mov	x9, #-0x28              // =-40
#     394c: 910043ea     	add	x10, sp, #0x10
#     3950: 910243eb     	add	x11, sp, #0x90
#     3954: f2dff009     	movk	x9, #0xff80, lsl #32
#     3958: 9102014a     	add	x10, x10, #0x80
#     395c: 910423e0     	add	x0, sp, #0x108
#     3960: a90fa7ea     	stp	x10, x9, [sp, #0xf8]
#     3964: 9100a169     	add	x9, x11, #0x28
#     3968: 9100c3ab     	add	x11, x29, #0x30
#     396c: 9103a3ea     	add	x10, sp, #0xe8
#     3970: a90ea7eb     	stp	x11, x9, [sp, #0xe8]
#     3974: 910303e3     	add	x3, sp, #0xc0
#     3978: ad400141     	ldp	q1, q0, [x10]
#     397c: 52802001     	mov	w1, #0x100              // =256
#     3980: aa0803e2     	mov	x2, x8
#     3984: ad0603e1     	stp	q1, q0, [sp, #0xc0]
#     3988: 94000c66     	bl	0x6b20 <vsnprintf@plt>
#     398c: 910423e0     	add	x0, sp, #0x108
#     3990: 94000c20     	bl	0x6a10 <strlen@plt>
#     3994: aa0003e9     	mov	x9, x0
#     3998: 9102e3e8     	add	x8, sp, #0xb8
#     399c: 910423e0     	add	x0, sp, #0x108
#     39a0: 91000521     	add	x1, x9, #0x1
#     39a4: aa1303e2     	mov	x2, x19
#     39a8: 9102e3f5     	add	x21, sp, #0xb8
#     39ac: 9400028c     	bl	0x43dc <.text+0x1428>
#     39b0: 91006273     	add	x19, x19, #0x18
#     39b4: eb15027f     	cmp	x19, x21
#     39b8: 540000c0     	b.eq	0x39d0 <.text+0xa1c>
#     39bc: f9400260     	ldr	x0, [x19]
#     39c0: 97fffebf     	bl	0x34bc <.text+0x508>
#     39c4: f9405fe8     	ldr	x8, [sp, #0xb8]
#     39c8: f9000268     	str	x8, [x19]
#     39cc: 17ffffd3     	b	0x3918 <.text+0x964>
#     39d0: f9405fe0     	ldr	x0, [sp, #0xb8]
#     39d4: b4fffa20     	cbz	x0, 0x3918 <.text+0x964>
#     39d8: 97fffeb9     	bl	0x34bc <.text+0x508>
#     39dc: 17ffffcf     	b	0x3918 <.text+0x964>
#     39e0: 94000c1c     	bl	0x6a50 <__stack_chk_fail@plt>
#     39e4: b9000fe1     	str	w1, [sp, #0xc]
#     39e8: b50001a8     	cbnz	x8, 0x3a1c <.text+0xa68>
#     39ec: b9400fe0     	ldr	w0, [sp, #0xc]
#     39f0: 94000042     	bl	0x3af8 <.text+0xb44>
#     39f4: b50002e0     	cbnz	x0, 0x3a50 <.text+0xa9c>
#     39f8: b9400ff4     	ldr	w20, [sp, #0xc]
#     39fc: 2a1403e0     	mov	w0, w20
#     3a00: 94000c10     	bl	0x6a40 <strerror@plt>
#     3a04: aa0003e3     	mov	x3, x0
#     3a08: d0ffffe1     	adrp	x1, 0x1000
#     3a0c: 91311c21     	add	x1, x1, #0xc47
#     3a10: aa1303e0     	mov	x0, x19
#     3a14: 2a1403e2     	mov	w2, w20
#     3a18: 94000011     	bl	0x3a5c <.text+0xaa8>
#     3a1c: 928004e9     	mov	x9, #-0x28              // =-40
#     3a20: 910043ea     	add	x10, sp, #0x10
#     3a24: 910243eb     	add	x11, sp, #0x90
#     3a28: f2dff009     	movk	x9, #0xff80, lsl #32
#     3a2c: 9102014a     	add	x10, x10, #0x80
#     3a30: 910423e2     	add	x2, sp, #0x108
#     3a34: a911a7ea     	stp	x10, x9, [sp, #0x118]
#     3a38: 9100c3a9     	add	x9, x29, #0x30
#     3a3c: 9100a16a     	add	x10, x11, #0x28
#     3a40: aa1303e0     	mov	x0, x19
#     3a44: aa0803e1     	mov	x1, x8
#     3a48: a910abe9     	stp	x9, x10, [sp, #0x108]
#     3a4c: 94000204     	bl	0x425c <.text+0x12a8>
#     3a50: aa0003e1     	mov	x1, x0
#     3a54: aa1303e0     	mov	x0, x19
#     3a58: 97fffe67     	bl	0x33f4 <.text+0x440>
#     3a5c: a9bd7bfd     	stp	x29, x30, [sp, #-0x30]!
#     3a60: a90157f6     	stp	x22, x21, [sp, #0x10]
#     3a64: a9024ff4     	stp	x20, x19, [sp, #0x20]
#     3a68: 910003fd     	mov	x29, sp
#     3a6c: aa0303f3     	mov	x19, x3
#     3a70: 2a0203f4     	mov	w20, w2
#     3a74: aa0103f5     	mov	x21, x1
#     3a78: aa0003f6     	mov	x22, x0
#     3a7c: 940001ce     	bl	0x41b4 <.text+0x1200>
#     3a80: aa1603e0     	mov	x0, x22
#     3a84: 94000209     	bl	0x42a8 <.text+0x12f4>
#     3a88: aa1603e0     	mov	x0, x22
#     3a8c: aa1503e1     	mov	x1, x21
#     3a90: 2a1403e2     	mov	w2, w20
#     3a94: aa1303e3     	mov	x3, x19
#     3a98: 94000014     	bl	0x3ae8 <.text+0xb34>
#     3a9c: aa1603e0     	mov	x0, x22
#     3aa0: 94000221     	bl	0x4324 <.text+0x1370>
#     3aa4: aa1f03e2     	mov	x2, xzr
#     3aa8: 17ffff68     	b	0x3848 <.text+0x894>
#     3aac: 12800001     	mov	w1, #-0x1               // =-1
#     3ab0: aa1f03e2     	mov	x2, xzr
#     3ab4: 17ffff65     	b	0x3848 <.text+0x894>
#     3ab8: a9be7bfd     	stp	x29, x30, [sp, #-0x20]!
#     3abc: f9000bf3     	str	x19, [sp, #0x10]
#     3ac0: 910003fd     	mov	x29, sp
#     3ac4: aa0003f3     	mov	x19, x0
#     3ac8: 94000bda     	bl	0x6a30 <__errno@plt>
#     3acc: aa0003e8     	mov	x8, x0
#     3ad0: aa1303e0     	mov	x0, x19
#     3ad4: b9400101     	ldr	w1, [x8]
#     3ad8: aa1f03e2     	mov	x2, xzr
#     3adc: f9400bf3     	ldr	x19, [sp, #0x10]
#     3ae0: a8c27bfd     	ldp	x29, x30, [sp], #0x20
#     3ae4: 17ffff59     	b	0x3848 <.text+0x894>
#     3ae8: f0000028     	adrp	x8, 0xa000 <memmove@plt+0x3440>
#     3aec: f9473d08     	ldr	x8, [x8, #0xe78]
#     3af0: f9400100     	ldr	x0, [x8]
#     3af4: 14000bcb     	b	0x6a20 <fprintf@plt>
#     3af8: 37f801a0     	tbnz	w0, #0x1f, 0x3b2c <.text+0xb78>
#     3afc: 510fa408     	sub	w8, w0, #0x3e9
#     3b00: 7100b91f     	cmp	w8, #0x2e
#     3b04: 54000268     	b.hi	0x3b50 <.text+0xb9c>
#     3b08: d0ffffe9     	adrp	x9, 0x1000
#     3b0c: 913d6529     	add	x9, x9, #0xf59
#     3b10: 1000008a     	adr	x10, 0x3b20 <.text+0xb6c>
#     3b14: 3868692b     	ldrb	w11, [x9, x8]
#     3b18: 8b0b094a     	add	x10, x10, x11, lsl #2
#     3b1c: d61f0140     	br	x10
#     3b20: d0ffffe0     	adrp	x0, 0x1000
#     3b24: 912d4800     	add	x0, x0, #0xb52
#     3b28: d65f03c0     	ret
#     3b2c: 31000c1f     	cmn	w0, #0x3
#     3b30: 540001c0     	b.eq	0x3b68 <.text+0xbb4>
#     3b34: 3100081f     	cmn	w0, #0x2
#     3b38: 540001e0     	b.eq	0x3b74 <.text+0xbc0>
#     3b3c: 3100041f     	cmn	w0, #0x1
#     3b40: 54000201     	b.ne	0x3b80 <.text+0xbcc>
#     3b44: d0ffffe0     	adrp	x0, 0x1000
#     3b48: 9105b400     	add	x0, x0, #0x16d
#     3b4c: d65f03c0     	ret
#     3b50: 340004c0     	cbz	w0, 0x3be8 <.text+0xc34>
#     3b54: 7104001f     	cmp	w0, #0x100
#     3b58: 54000141     	b.ne	0x3b80 <.text+0xbcc>
#     3b5c: d0ffffe0     	adrp	x0, 0x1000
#     3b60: 910d5800     	add	x0, x0, #0x356
#     3b64: d65f03c0     	ret
#     3b68: d0ffffe0     	adrp	x0, 0x1000
#     3b6c: 91373c00     	add	x0, x0, #0xdcf
#     3b70: d65f03c0     	ret
#     3b74: d0ffffe0     	adrp	x0, 0x1000
#     3b78: 911a1400     	add	x0, x0, #0x685
#     3b7c: d65f03c0     	ret
#     3b80: aa1f03e0     	mov	x0, xzr
#     3b84: d65f03c0     	ret
#     3b88: d0ffffe0     	adrp	x0, 0x1000
#     3b8c: 911f5c00     	add	x0, x0, #0x7d7
#     3b90: d65f03c0     	ret
#     3b94: d0ffffe0     	adrp	x0, 0x1000
#     3b98: 912e1c00     	add	x0, x0, #0xb87
#     3b9c: d65f03c0     	ret
#     3ba0: d0ffffe0     	adrp	x0, 0x1000
#     3ba4: 912d7000     	add	x0, x0, #0xb5c
#     3ba8: d65f03c0     	ret
#     3bac: d0ffffe0     	adrp	x0, 0x1000
#     3bb0: 91201400     	add	x0, x0, #0x805
#     3bb4: d65f03c0     	ret
#     3bb8: d0ffffe0     	adrp	x0, 0x1000
#     3bbc: 911f0800     	add	x0, x0, #0x7c2
#     3bc0: d65f03c0     	ret
#     3bc4: d0ffffe0     	adrp	x0, 0x1000
#     3bc8: 911c1400     	add	x0, x0, #0x705
#     3bcc: d65f03c0     	ret
#     3bd0: d0ffffe0     	adrp	x0, 0x1000
#     3bd4: 91378800     	add	x0, x0, #0xde2
#     3bd8: d65f03c0     	ret
#     3bdc: d0ffffe0     	adrp	x0, 0x1000
#     3be0: 910e8c00     	add	x0, x0, #0x3a3
#     3be4: d65f03c0     	ret
#     3be8: d0ffffe0     	adrp	x0, 0x1000
#     3bec: 913cac00     	add	x0, x0, #0xf2b
#     3bf0: d65f03c0     	ret
#     3bf4: d0ffffe0     	adrp	x0, 0x1000
#     3bf8: 91167c00     	add	x0, x0, #0x59f
#     3bfc: d65f03c0     	ret
#     3c00: d0ffffe0     	adrp	x0, 0x1000
#     3c04: 91236400     	add	x0, x0, #0x8d9
#     3c08: d65f03c0     	ret
#     3c0c: d0ffffe0     	adrp	x0, 0x1000
#     3c10: 91068c00     	add	x0, x0, #0x1a3
#     3c14: d65f03c0     	ret
#     3c18: d0ffffe0     	adrp	x0, 0x1000
#     3c1c: 910e6000     	add	x0, x0, #0x398
#     3c20: d65f03c0     	ret
#     3c24: d0ffffe0     	adrp	x0, 0x1000
#     3c28: 91126000     	add	x0, x0, #0x498
#     3c2c: d65f03c0     	ret
#     3c30: d0ffffe0     	adrp	x0, 0x1000
#     3c34: 913cd000     	add	x0, x0, #0xf34
#     3c38: d65f03c0     	ret
#     3c3c: d0ffffe0     	adrp	x0, 0x1000
#     3c40: 91061800     	add	x0, x0, #0x186
#     3c44: d65f03c0     	ret
#     3c48: d0ffffe0     	adrp	x0, 0x1000
#     3c4c: 912ba400     	add	x0, x0, #0xae9
#     3c50: d65f03c0     	ret
#     3c54: d0ffffe0     	adrp	x0, 0x1000
#     3c58: 911b4800     	add	x0, x0, #0x6d2
#     3c5c: d65f03c0     	ret
#     3c60: d0ffffe0     	adrp	x0, 0x1000
#     3c64: 910f7800     	add	x0, x0, #0x3de
#     3c68: d65f03c0     	ret
#     3c6c: d0ffffe0     	adrp	x0, 0x1000
#     3c70: 91006000     	add	x0, x0, #0x18
#     3c74: d65f03c0     	ret
#     3c78: d0ffffe0     	adrp	x0, 0x1000
#     3c7c: 910dbc00     	add	x0, x0, #0x36f
#     3c80: d65f03c0     	ret
#     3c84: d0ffffe0     	adrp	x0, 0x1000
#     3c88: 912b3c00     	add	x0, x0, #0xacf
#     3c8c: d65f03c0     	ret
#     3c90: d0ffffe0     	adrp	x0, 0x1000
#     3c94: 9124fc00     	add	x0, x0, #0x93f
#     3c98: d65f03c0     	ret
#     3c9c: d0ffffe0     	adrp	x0, 0x1000
#     3ca0: 91188000     	add	x0, x0, #0x620
#     3ca4: d65f03c0     	ret
#     3ca8: d0ffffe0     	adrp	x0, 0x1000
#     3cac: 91025c00     	add	x0, x0, #0x97
#     3cb0: d65f03c0     	ret
#     3cb4: d0ffffe0     	adrp	x0, 0x1000
#     3cb8: 91108000     	add	x0, x0, #0x420
#     3cbc: d65f03c0     	ret
#     3cc0: d0ffffe0     	adrp	x0, 0x1000
#     3cc4: 91318000     	add	x0, x0, #0xc60
#     3cc8: d65f03c0     	ret
#     3ccc: d0ffffe0     	adrp	x0, 0x1000
#     3cd0: 91101400     	add	x0, x0, #0x405
#     3cd4: d65f03c0     	ret
#     3cd8: d0ffffe0     	adrp	x0, 0x1000
#     3cdc: 9129a800     	add	x0, x0, #0xa6a
#     3ce0: d65f03c0     	ret
#     3ce4: d0ffffe0     	adrp	x0, 0x1000
#     3ce8: 91073c00     	add	x0, x0, #0x1cf
#     3cec: d65f03c0     	ret
#     3cf0: d0ffffe0     	adrp	x0, 0x1000
#     3cf4: 91160400     	add	x0, x0, #0x581
#     3cf8: d65f03c0     	ret
#     3cfc: d0ffffe0     	adrp	x0, 0x1000
#     3d00: 911cb000     	add	x0, x0, #0x72c
#     3d04: d65f03c0     	ret
#     3d08: d0ffffe0     	adrp	x0, 0x1000
#     3d0c: 91259400     	add	x0, x0, #0x965
#     3d10: d65f03c0     	ret
#     3d14: b0ffffe0     	adrp	x0, 0x0
#     3d18: 913ff800     	add	x0, x0, #0xffe
#     3d1c: d65f03c0     	ret
#     3d20: d0ffffe0     	adrp	x0, 0x1000
#     3d24: 9100d800     	add	x0, x0, #0x36
#     3d28: d65f03c0     	ret
#     3d2c: d0ffffe0     	adrp	x0, 0x1000
#     3d30: 91346c00     	add	x0, x0, #0xd1b
#     3d34: d65f03c0     	ret
#     3d38: d0ffffe0     	adrp	x0, 0x1000
#     3d3c: 91383c00     	add	x0, x0, #0xe0f
#     3d40: d65f03c0     	ret
#     3d44: d0ffffe0     	adrp	x0, 0x1000
#     3d48: 911ab800     	add	x0, x0, #0x6ae
#     3d4c: d65f03c0     	ret
#     3d50: d0ffffe0     	adrp	x0, 0x1000
#     3d54: 9120d000     	add	x0, x0, #0x834
#     3d58: d65f03c0     	ret
#     3d5c: d0ffffe0     	adrp	x0, 0x1000
#     3d60: 911e3800     	add	x0, x0, #0x78e
#     3d64: d65f03c0     	ret
#     3d68: d0ffffe0     	adrp	x0, 0x1000
#     3d6c: 91083000     	add	x0, x0, #0x20c
#     3d70: d65f03c0     	ret
#     3d74: d0ffffe0     	adrp	x0, 0x1000
#     3d78: 9116e400     	add	x0, x0, #0x5b9
#     3d7c: d65f03c0     	ret
#     3d80: d0ffffe0     	adrp	x0, 0x1000
#     3d84: 9107c000     	add	x0, x0, #0x1f0
#     3d88: d65f03c0     	ret
#     3d8c: d0ffffe0     	adrp	x0, 0x1000
#     3d90: 9137e800     	add	x0, x0, #0xdfa
#     3d94: d65f03c0     	ret
#     3d98: d0ffffe0     	adrp	x0, 0x1000
#     3d9c: 9123f800     	add	x0, x0, #0x8fe
#     3da0: d65f03c0     	ret
#     3da4: d0ffffe0     	adrp	x0, 0x1000
#     3da8: 91228800     	add	x0, x0, #0x8a2
#     3dac: d65f03c0     	ret
#     3db0: d0ffffe0     	adrp	x0, 0x1000
#     3db4: 91219400     	add	x0, x0, #0x865
#     3db8: d65f03c0     	ret
#     3dbc: a9be7bfd     	stp	x29, x30, [sp, #-0x20]!
#     3dc0: a9014ff4     	stp	x20, x19, [sp, #0x10]
#     3dc4: 910003fd     	mov	x29, sp
#     3dc8: aa0003f3     	mov	x19, x0
#     3dcc: b9400000     	ldr	w0, [x0]
#     3dd0: 37f80140     	tbnz	w0, #0x1f, 0x3df8 <.text+0xe44>
#     3dd4: 71000c1f     	cmp	w0, #0x3
#     3dd8: 540000c3     	b.lo	0x3df0 <.text+0xe3c>
#     3ddc: aa0103f4     	mov	x20, x1
#     3de0: 94000b5c     	bl	0x6b50 <close@plt>
#     3de4: 34000060     	cbz	w0, 0x3df0 <.text+0xe3c>
#     3de8: aa1403e0     	mov	x0, x20
#     3dec: 97ffff33     	bl	0x3ab8 <.text+0xb04>
#     3df0: 12800008     	mov	w8, #-0x1               // =-1
#     3df4: b9000268     	str	w8, [x19]
#     3df8: a9414ff4     	ldp	x20, x19, [sp, #0x10]
#     3dfc: a8c27bfd     	ldp	x29, x30, [sp], #0x20
#     3e00: d65f03c0     	ret
#     3e04: a9bd7bfd     	stp	x29, x30, [sp, #-0x30]!
#     3e08: f9000bf5     	str	x21, [sp, #0x10]
#     3e0c: a9024ff4     	stp	x20, x19, [sp, #0x20]
#     3e10: 910003fd     	mov	x29, sp
#     3e14: aa0003f4     	mov	x20, x0
#     3e18: f9402400     	ldr	x0, [x0, #0x48]
#     3e1c: aa0203f3     	mov	x19, x2
#     3e20: 2a0103f5     	mov	w21, w1
#     3e24: f900269f     	str	xzr, [x20, #0x48]
#     3e28: b4000040     	cbz	x0, 0x3e30 <.text+0xe7c>
#     3e2c: 97fffda4     	bl	0x34bc <.text+0x508>
#     3e30: 3940e288     	ldrb	w8, [x20, #0x38]
#     3e34: 34000048     	cbz	w8, 0x3e3c <.text+0xe88>
#     3e38: 3900e29f     	strb	wzr, [x20, #0x38]
#     3e3c: 710006bf     	cmp	w21, #0x1
#     3e40: 54000081     	b.ne	0x3e50 <.text+0xe9c>
#     3e44: f9400680     	ldr	x0, [x20, #0x8]
#     3e48: b4000040     	cbz	x0, 0x3e50 <.text+0xe9c>
#     3e4c: 94000b39     	bl	0x6b30 <unlink@plt>
#     3e50: f9400680     	ldr	x0, [x20, #0x8]
#     3e54: f900069f     	str	xzr, [x20, #0x8]
#     3e58: b4000040     	cbz	x0, 0x3e60 <.text+0xeac>
#     3e5c: 97fffd98     	bl	0x34bc <.text+0x508>
#     3e60: aa1403e0     	mov	x0, x20
#     3e64: aa1303e1     	mov	x1, x19
#     3e68: a9424ff4     	ldp	x20, x19, [sp, #0x20]
#     3e6c: f9400bf5     	ldr	x21, [sp, #0x10]
#     3e70: a8c37bfd     	ldp	x29, x30, [sp], #0x30
#     3e74: 17ffffd2     	b	0x3dbc <.text+0xe08>
#     3e78: a9bb7bfd     	stp	x29, x30, [sp, #-0x50]!
#     3e7c: f9000bf9     	str	x25, [sp, #0x10]
#     3e80: a9025ff8     	stp	x24, x23, [sp, #0x20]
#     3e84: a90357f6     	stp	x22, x21, [sp, #0x30]
#     3e88: a9044ff4     	stp	x20, x19, [sp, #0x40]
#     3e8c: 910003fd     	mov	x29, sp
#     3e90: b4000644     	cbz	x4, 0x3f58 <.text+0xfa4>
#     3e94: b9400008     	ldr	w8, [x0]
#     3e98: aa0503f3     	mov	x19, x5
#     3e9c: aa0003f6     	mov	x22, x0
#     3ea0: 37f806c8     	tbnz	w8, #0x1f, 0x3f78 <.text+0xfc4>
#     3ea4: aa0203f5     	mov	x21, x2
#     3ea8: aa1603e0     	mov	x0, x22
#     3eac: aa1303e2     	mov	x2, x19
#     3eb0: aa0403f4     	mov	x20, x4
#     3eb4: aa0303f8     	mov	x24, x3
#     3eb8: 94000037     	bl	0x3f94 <.text+0xfe0>
#     3ebc: 360004e0     	tbz	w0, #0x0, 0x3f58 <.text+0xfa4>
#     3ec0: eb18029f     	cmp	x20, x24
#     3ec4: aa1f03f7     	mov	x23, xzr
#     3ec8: 9a983299     	csel	x25, x20, x24, lo
#     3ecc: eb1902ff     	cmp	x23, x25
#     3ed0: 54000462     	b.hs	0x3f5c <.text+0xfa8>
#     3ed4: b94002c0     	ldr	w0, [x22]
#     3ed8: cb170282     	sub	x2, x20, x23
#     3edc: 8b1702a1     	add	x1, x21, x23
#     3ee0: 94000b20     	bl	0x6b60 <read@plt>
#     3ee4: b40003c0     	cbz	x0, 0x3f5c <.text+0xfa8>
#     3ee8: b7f80140     	tbnz	x0, #0x3f, 0x3f10 <.text+0xf5c>
#     3eec: f94016c8     	ldr	x8, [x22, #0x28]
#     3ef0: 394082c9     	ldrb	w9, [x22, #0x20]
#     3ef4: 8b000108     	add	x8, x8, x0
#     3ef8: f90016c8     	str	x8, [x22, #0x28]
#     3efc: 34000049     	cbz	w9, 0x3f04 <.text+0xf50>
#     3f00: 390082df     	strb	wzr, [x22, #0x20]
#     3f04: 2a1f03e8     	mov	w8, wzr
#     3f08: 8b170017     	add	x23, x0, x23
#     3f0c: 14000011     	b	0x3f50 <.text+0xf9c>
#     3f10: 94000ac8     	bl	0x6a30 <__errno@plt>
#     3f14: b9400018     	ldr	w24, [x0]
#     3f18: 2a1f03e8     	mov	w8, wzr
#     3f1c: 7100131f     	cmp	w24, #0x4
#     3f20: 540000e0     	b.eq	0x3f3c <.text+0xf88>
#     3f24: 71002f1f     	cmp	w24, #0xb
#     3f28: 540000a0     	b.eq	0x3f3c <.text+0xf88>
#     3f2c: aa1303e0     	mov	x0, x19
#     3f30: 2a1803e1     	mov	w1, w24
#     3f34: 97fffedc     	bl	0x3aa4 <.text+0xaf0>
#     3f38: 52800068     	mov	w8, #0x3                // =3
#     3f3c: 7100131f     	cmp	w24, #0x4
#     3f40: 54000060     	b.eq	0x3f4c <.text+0xf98>
#     3f44: 71002f1f     	cmp	w24, #0xb
#     3f48: 54000041     	b.ne	0x3f50 <.text+0xf9c>
#     3f4c: 2a1f03e8     	mov	w8, wzr
#     3f50: 34fffbe8     	cbz	w8, 0x3ecc <.text+0xf18>
#     3f54: 14000002     	b	0x3f5c <.text+0xfa8>
#     3f58: aa1f03f7     	mov	x23, xzr
#     3f5c: aa1703e0     	mov	x0, x23
#     3f60: a9444ff4     	ldp	x20, x19, [sp, #0x40]
#     3f64: f9400bf9     	ldr	x25, [sp, #0x10]
#     3f68: a94357f6     	ldp	x22, x21, [sp, #0x30]
#     3f6c: a9425ff8     	ldp	x24, x23, [sp, #0x20]
#     3f70: a8c57bfd     	ldp	x29, x30, [sp], #0x50
#     3f74: d65f03c0     	ret
#     3f78: d0ffffe1     	adrp	x1, 0x1000
#     3f7c: 911d3821     	add	x1, x1, #0x74e
#     3f80: d0ffffe2     	adrp	x2, 0x1000
#     3f84: 9102e442     	add	x2, x2, #0xb9
#     3f88: aa1303e0     	mov	x0, x19
#     3f8c: 52802e63     	mov	w3, #0x173              // =371
#     3f90: 940000f1     	bl	0x4354 <.text+0x13a0>
#     3f94: f9401408     	ldr	x8, [x0, #0x28]
#     3f98: eb01011f     	cmp	x8, x1
#     3f9c: 54000061     	b.ne	0x3fa8 <.text+0xff4>
#     3fa0: 52800020     	mov	w0, #0x1                // =1
#     3fa4: d65f03c0     	ret
#     3fa8: a9bd7bfd     	stp	x29, x30, [sp, #-0x30]!
#     3fac: f9000bf5     	str	x21, [sp, #0x10]
#     3fb0: a9024ff4     	stp	x20, x19, [sp, #0x20]
#     3fb4: 910003fd     	mov	x29, sp
#     3fb8: aa0003f3     	mov	x19, x0
#     3fbc: b9400000     	ldr	w0, [x0]
#     3fc0: aa0203f5     	mov	x21, x2
#     3fc4: 2a1f03e2     	mov	w2, wzr
#     3fc8: aa0103f4     	mov	x20, x1
#     3fcc: 94000add     	bl	0x6b40 <lseek@plt>
#     3fd0: eb14001f     	cmp	x0, x20
#     3fd4: 540000e1     	b.ne	0x3ff0 <.text+0x103c>
#     3fd8: 39408268     	ldrb	w8, [x19, #0x20]
#     3fdc: f9001674     	str	x20, [x19, #0x28]
#     3fe0: 34000048     	cbz	w8, 0x3fe8 <.text+0x1034>
#     3fe4: 3900827f     	strb	wzr, [x19, #0x20]
#     3fe8: 52800020     	mov	w0, #0x1                // =1
#     3fec: 14000005     	b	0x4000 <.text+0x104c>
#     3ff0: aa1503e0     	mov	x0, x21
#     3ff4: 528081c1     	mov	w1, #0x40e              // =1038
#     3ff8: 97fffeab     	bl	0x3aa4 <.text+0xaf0>
#     3ffc: 2a1f03e0     	mov	w0, wzr
#     4000: a9424ff4     	ldp	x20, x19, [sp, #0x20]
#     4004: f9400bf5     	ldr	x21, [sp, #0x10]
#     4008: a8c37bfd     	ldp	x29, x30, [sp], #0x30
#     400c: d65f03c0     	ret
#     4010: a9bc7bfd     	stp	x29, x30, [sp, #-0x40]!
#     4014: a9015ff8     	stp	x24, x23, [sp, #0x10]
#     4018: a90257f6     	stp	x22, x21, [sp, #0x20]
#     401c: a9034ff4     	stp	x20, x19, [sp, #0x30]
#     4020: 910003fd     	mov	x29, sp
#     4024: b40006a3     	cbz	x3, 0x40f8 <.text+0x1144>
#     4028: b9400008     	ldr	w8, [x0]
#     402c: aa0403f5     	mov	x21, x4
#     4030: aa0003f3     	mov	x19, x0
#     4034: 37f80708     	tbnz	w8, #0x1f, 0x4114 <.text+0x1160>
#     4038: aa0203f7     	mov	x23, x2
#     403c: aa1303e0     	mov	x0, x19
#     4040: aa1503e2     	mov	x2, x21
#     4044: aa0303f6     	mov	x22, x3
#     4048: 97ffffd3     	bl	0x3f94 <.text+0xfe0>
#     404c: 36000560     	tbz	w0, #0x0, 0x40f8 <.text+0x1144>
#     4050: aa1f03f4     	mov	x20, xzr
#     4054: eb1402c2     	subs	x2, x22, x20
#     4058: 540003e9     	b.ls	0x40d4 <.text+0x1120>
#     405c: b9400260     	ldr	w0, [x19]
#     4060: 8b1402e1     	add	x1, x23, x20
#     4064: 94000ac3     	bl	0x6b70 <write@plt>
#     4068: b7f80140     	tbnz	x0, #0x3f, 0x4090 <.text+0x10dc>
#     406c: f9401668     	ldr	x8, [x19, #0x28]
#     4070: 39408269     	ldrb	w9, [x19, #0x20]
#     4074: 8b000108     	add	x8, x8, x0
#     4078: f9001668     	str	x8, [x19, #0x28]
#     407c: 34000049     	cbz	w9, 0x4084 <.text+0x10d0>
#     4080: 3900827f     	strb	wzr, [x19, #0x20]
#     4084: 2a1f03e8     	mov	w8, wzr
#     4088: 8b140014     	add	x20, x0, x20
#     408c: 14000011     	b	0x40d0 <.text+0x111c>
#     4090: 94000a68     	bl	0x6a30 <__errno@plt>
#     4094: b9400018     	ldr	w24, [x0]
#     4098: 2a1f03e8     	mov	w8, wzr
#     409c: 7100131f     	cmp	w24, #0x4
#     40a0: 540000e0     	b.eq	0x40bc <.text+0x1108>
#     40a4: 71002f1f     	cmp	w24, #0xb
#     40a8: 540000a0     	b.eq	0x40bc <.text+0x1108>
#     40ac: aa1503e0     	mov	x0, x21
#     40b0: 2a1803e1     	mov	w1, w24
#     40b4: 97fffe7c     	bl	0x3aa4 <.text+0xaf0>
#     40b8: 52800068     	mov	w8, #0x3                // =3
#     40bc: 71002f1f     	cmp	w24, #0xb
#     40c0: 54000060     	b.eq	0x40cc <.text+0x1118>
#     40c4: 7100131f     	cmp	w24, #0x4
#     40c8: 54000041     	b.ne	0x40d0 <.text+0x111c>
#     40cc: 2a1f03e8     	mov	w8, wzr
#     40d0: 34fffc28     	cbz	w8, 0x4054 <.text+0x10a0>
#     40d4: 3940e268     	ldrb	w8, [x19, #0x38]
#     40d8: 34000128     	cbz	w8, 0x40fc <.text+0x1148>
#     40dc: a942a668     	ldp	x8, x9, [x19, #0x28]
#     40e0: eb09011f     	cmp	x8, x9
# ...
#     669c: 1a8a016c     	csel	w12, w11, w10, eq
#     66a0: 1a8d012d     	csel	w13, w9, w13, eq
#     66a4: 1a8b014a     	csel	w10, w10, w11, eq
#     66a8: 53101d8c     	ubfiz	w12, w12, #16, #8
#     66ac: 1a890108     	csel	w8, w8, w9, eq
#     66b0: 2a0d6180     	orr	w0, w12, w13, lsl #24
#     66b4: 33181d40     	bfi	w0, w10, #8, #8
#     66b8: 33001d00     	bfxil	w0, w8, #0, #8
#     66bc: d65f03c0     	ret
#     66c0: a9bd7bfd     	stp	x29, x30, [sp, #-0x30]!
#     66c4: f9000bf5     	str	x21, [sp, #0x10]
#     66c8: a9024ff4     	stp	x20, x19, [sp, #0x20]
#     66cc: 910003fd     	mov	x29, sp
#     66d0: f9400415     	ldr	x21, [x0, #0x8]
#     66d4: eb0102bf     	cmp	x21, x1
#     66d8: 5400036a     	b.ge	0x6744 <.text+0x3790>
#     66dc: 914042a8     	add	x8, x21, #0x10, lsl #12 // =0x10000
#     66e0: aa0003f3     	mov	x19, x0
#     66e4: f9400014     	ldr	x20, [x0]
#     66e8: eb01011f     	cmp	x8, x1
#     66ec: 9a81c101     	csel	x1, x8, x1, gt
#     66f0: f9000401     	str	x1, [x0, #0x8]
#     66f4: aa0203e0     	mov	x0, x2
#     66f8: 97fff350     	bl	0x3438 <.text+0x484>
#     66fc: f9000260     	str	x0, [x19]
#     6700: b4000214     	cbz	x20, 0x6740 <.text+0x378c>
#     6704: a941a668     	ldp	x8, x9, [x19, #0x18]
#     6708: cb0802aa     	sub	x10, x21, x8
#     670c: 8b080281     	add	x1, x20, x8
#     6710: eb09015f     	cmp	x10, x9
#     6714: 9a89b155     	csel	x21, x10, x9, lt
#     6718: aa1503e2     	mov	x2, x21
#     671c: 94000121     	bl	0x6ba0 <memcpy@plt>
#     6720: f9401268     	ldr	x8, [x19, #0x20]
#     6724: f9400269     	ldr	x9, [x19]
#     6728: aa1403e1     	mov	x1, x20
#     672c: cb150102     	sub	x2, x8, x21
#     6730: 8b150120     	add	x0, x9, x21
#     6734: 9400011b     	bl	0x6ba0 <memcpy@plt>
#     6738: aa1403e0     	mov	x0, x20
#     673c: 97fff360     	bl	0x34bc <.text+0x508>
#     6740: f9000e7f     	str	xzr, [x19, #0x18]
#     6744: a9424ff4     	ldp	x20, x19, [sp, #0x20]
#     6748: f9400bf5     	ldr	x21, [sp, #0x10]
#     674c: a8c37bfd     	ldp	x29, x30, [sp], #0x30
#     6750: d65f03c0     	ret
#     6754: a9be7bfd     	stp	x29, x30, [sp, #-0x20]!
#     6758: a9014ff4     	stp	x20, x19, [sp, #0x10]
#     675c: 910003fd     	mov	x29, sp
#     6760: f9400c08     	ldr	x8, [x0, #0x18]
#     6764: f9400409     	ldr	x9, [x0, #0x8]
#     6768: 8b02010a     	add	x10, x8, x2
#     676c: eb09015f     	cmp	x10, x9
#     6770: 540002ed     	b.le	0x67cc <.text+0x3818>
#     6774: f9401002     	ldr	x2, [x0, #0x20]
#     6778: aa0003f3     	mov	x19, x0
#     677c: eb09005f     	cmp	x2, x9
#     6780: 540002ca     	b.ge	0x67d8 <.text+0x3824>
#     6784: 8b08004a     	add	x10, x2, x8
#     6788: eb090154     	subs	x20, x10, x9
#     678c: 5400018d     	b.le	0x67bc <.text+0x3808>
#     6790: eb140042     	subs	x2, x2, x20
#     6794: 5400032b     	b.lt	0x67f8 <.text+0x3844>
#     6798: f9400269     	ldr	x9, [x19]
#     679c: 8b140120     	add	x0, x9, x20
#     67a0: 8b080121     	add	x1, x9, x8
#     67a4: 94000107     	bl	0x6bc0 <memmove@plt>
#     67a8: f9400260     	ldr	x0, [x19]
#     67ac: f9401261     	ldr	x1, [x19, #0x20]
#     67b0: aa1403e2     	mov	x2, x20
#     67b4: 94000039     	bl	0x6898 <.text+0x38e4>
#     67b8: 14000004     	b	0x67c8 <.text+0x3814>
#     67bc: f9400260     	ldr	x0, [x19]
#     67c0: 8b080001     	add	x1, x0, x8
#     67c4: 940000ff     	bl	0x6bc0 <memmove@plt>
#     67c8: f9000e7f     	str	xzr, [x19, #0x18]
#     67cc: a9414ff4     	ldp	x20, x19, [sp, #0x10]
#     67d0: a8c27bfd     	ldp	x29, x30, [sp], #0x20
#     67d4: d65f03c0     	ret
#     67d8: f0ffffc8     	adrp	x8, 0x1000
#     67dc: 91353d08     	add	x8, x8, #0xd4f
#     67e0: f0ffffc2     	adrp	x2, 0x1000
#     67e4: 913bbc42     	add	x2, x2, #0xeef
#     67e8: aa0103e0     	mov	x0, x1
#     67ec: aa0803e1     	mov	x1, x8
#     67f0: 52801903     	mov	w3, #0xc8               // =200
#     67f4: 97fff6d8     	bl	0x4354 <.text+0x13a0>
#     67f8: f0ffffc8     	adrp	x8, 0x1000
#     67fc: 912ad508     	add	x8, x8, #0xab5
#     6800: f0ffffc2     	adrp	x2, 0x1000
#     6804: 913bbc42     	add	x2, x2, #0xeef
#     6808: aa0103e0     	mov	x0, x1
#     680c: aa0803e1     	mov	x1, x8
#     6810: 528019e3     	mov	w3, #0xcf               // =207
#     6814: 97fff6d0     	bl	0x4354 <.text+0x13a0>
#     6818: f9401008     	ldr	x8, [x0, #0x20]
#     681c: eb010108     	subs	x8, x8, x1
#     6820: 5400028b     	b.lt	0x6870 <.text+0x38bc>
#     6824: f9001008     	str	x8, [x0, #0x20]
#     6828: 54000061     	b.ne	0x6834 <.text+0x3880>
#     682c: aa1f03e8     	mov	x8, xzr
#     6830: 14000007     	b	0x684c <.text+0x3898>
#     6834: f9400c08     	ldr	x8, [x0, #0x18]
#     6838: f9400409     	ldr	x9, [x0, #0x8]
#     683c: 8b01010a     	add	x10, x8, x1
#     6840: eb090148     	subs	x8, x10, x9
#     6844: f9000c0a     	str	x10, [x0, #0x18]
#     6848: 5400004b     	b.lt	0x6850 <.text+0x389c>
#     684c: f9000c08     	str	x8, [x0, #0x18]
#     6850: f9401408     	ldr	x8, [x0, #0x28]
#     6854: f9400809     	ldr	x9, [x0, #0x10]
#     6858: eb010108     	subs	x8, x8, x1
#     685c: 8b010129     	add	x9, x9, x1
#     6860: 9a88b3e8     	csel	x8, xzr, x8, lt
#     6864: f9000809     	str	x9, [x0, #0x10]
#     6868: f9001408     	str	x8, [x0, #0x28]
#     686c: d65f03c0     	ret
#     6870: a9bf7bfd     	stp	x29, x30, [sp, #-0x10]!
#     6874: 910003fd     	mov	x29, sp
#     6878: f0ffffc8     	adrp	x8, 0x1000
#     687c: 913bbd08     	add	x8, x8, #0xeef
#     6880: f0ffffc1     	adrp	x1, 0x1000
#     6884: 912ad421     	add	x1, x1, #0xab5
#     6888: aa0203e0     	mov	x0, x2
#     688c: aa0803e2     	mov	x2, x8
#     6890: 52801623     	mov	w3, #0xb1               // =177
#     6894: 97fff6b0     	bl	0x4354 <.text+0x13a0>
#     6898: b40001a2     	cbz	x2, 0x68cc <.text+0x3918>
#     689c: 8b020008     	add	x8, x0, x2
#     68a0: d1000508     	sub	x8, x8, #0x1
#     68a4: eb00011f     	cmp	x8, x0
#     68a8: 54000129     	b.ls	0x68cc <.text+0x3918>
#     68ac: 91000409     	add	x9, x0, #0x1
#     68b0: 3940010a     	ldrb	w10, [x8]
#     68b4: 385ff12b     	ldurb	w11, [x9, #-0x1]
#     68b8: 381ff12a     	sturb	w10, [x9, #-0x1]
#     68bc: 381ff50b     	strb	w11, [x8], #-0x1
#     68c0: eb08013f     	cmp	x9, x8
#     68c4: 91000529     	add	x9, x9, #0x1
#     68c8: 54ffff43     	b.lo	0x68b0 <.text+0x38fc>
#     68cc: 8b010008     	add	x8, x0, x1
#     68d0: b4000181     	cbz	x1, 0x6900 <.text+0x394c>
#     68d4: d1000509     	sub	x9, x8, #0x1
#     68d8: eb00013f     	cmp	x9, x0
#     68dc: 54000129     	b.ls	0x6900 <.text+0x394c>
#     68e0: 9100040a     	add	x10, x0, #0x1
#     68e4: 3940012b     	ldrb	w11, [x9]
#     68e8: 385ff14c     	ldurb	w12, [x10, #-0x1]
#     68ec: 381ff14b     	sturb	w11, [x10, #-0x1]
#     68f0: 381ff52c     	strb	w12, [x9], #-0x1
#     68f4: eb09015f     	cmp	x10, x9
#     68f8: 9100054a     	add	x10, x10, #0x1
#     68fc: 54ffff43     	b.lo	0x68e4 <.text+0x3930>
#     6900: cb020108     	sub	x8, x8, x2
#     6904: eb00011f     	cmp	x8, x0
#     6908: 54000180     	b.eq	0x6938 <.text+0x3984>
#     690c: d1000508     	sub	x8, x8, #0x1
#     6910: eb00011f     	cmp	x8, x0
#     6914: 54000129     	b.ls	0x6938 <.text+0x3984>
#     6918: 91000409     	add	x9, x0, #0x1
#     691c: 3940010a     	ldrb	w10, [x8]
#     6920: 385ff12b     	ldurb	w11, [x9, #-0x1]
#     6924: 381ff12a     	sturb	w10, [x9, #-0x1]
#     6928: 381ff50b     	strb	w11, [x8], #-0x1
#     692c: eb08013f     	cmp	x9, x8
#     6930: 91000529     	add	x9, x9, #0x1
#     6934: 54ffff43     	b.lo	0x691c <.text+0x3968>
#     6938: d65f03c0     	ret
#     693c: a9bf7bfd     	stp	x29, x30, [sp, #-0x10]!
#     6940: 910003fd     	mov	x29, sp
#     6944: aa1f03e3     	mov	x3, xzr
#     6948: 97fff1db     	bl	0x30b4 <.text+0x100>
#     694c: 52800540     	mov	w0, #0x2a               // =42
#     6950: 97fff302     	bl	0x3558 <.text+0x5a4>
#     6954: 97fff2fa     	bl	0x353c <.text+0x588>
#     6958: 2a1f03e0     	mov	w0, wzr
#     695c: a8c17bfd     	ldp	x29, x30, [sp], #0x10
#     6960: d65f03c0     	ret
#
# Disassembly of section .plt:
#
# 0000000000006970 <.plt>:
#     6970: a9bf7bf0     	stp	x16, x30, [sp, #-0x10]!
#     6974: 90000030     	adrp	x16, 0xa000 <memmove@plt+0x3440>
#     6978: f9475611     	ldr	x17, [x16, #0xea8]
#     697c: 913aa210     	add	x16, x16, #0xea8
#     6980: d61f0220     	br	x17
#     6984: d503201f     	nop
#     6988: d503201f     	nop
#     698c: d503201f     	nop
#
# 0000000000006990 <__libc_init@plt>:
#     6990: 90000030     	adrp	x16, 0xa000 <memmove@plt+0x3440>
#     6994: f9475a11     	ldr	x17, [x16, #0xeb0]
#     6998: 913ac210     	add	x16, x16, #0xeb0
#     699c: d61f0220     	br	x17
#
# 00000000000069a0 <__cxa_atexit@plt>:
#     69a0: 90000030     	adrp	x16, 0xa000 <memmove@plt+0x3440>
#     69a4: f9475e11     	ldr	x17, [x16, #0xeb8]
#     69a8: 913ae210     	add	x16, x16, #0xeb8
#     69ac: d61f0220     	br	x17
#
# 00000000000069b0 <__register_atfork@plt>:
#     69b0: 90000030     	adrp	x16, 0xa000 <memmove@plt+0x3440>
#     69b4: f9476211     	ldr	x17, [x16, #0xec0]
#     69b8: 913b0210     	add	x16, x16, #0xec0
#     69bc: d61f0220     	br	x17
#
# 00000000000069c0 <feclearexcept@plt>:
#     69c0: 90000030     	adrp	x16, 0xa000 <memmove@plt+0x3440>
#     69c4: f9476611     	ldr	x17, [x16, #0xec8]
#     69c8: 913b2210     	add	x16, x16, #0xec8
#     69cc: d61f0220     	br	x17
#
# 00000000000069d0 <fesetround@plt>:
#     69d0: 90000030     	adrp	x16, 0xa000 <memmove@plt+0x3440>
#     69d4: f9476a11     	ldr	x17, [x16, #0xed0]
#     69d8: 913b4210     	add	x16, x16, #0xed0
#     69dc: d61f0220     	br	x17
#
# 00000000000069e0 <setenv@plt>:
#     69e0: 90000030     	adrp	x16, 0xa000 <memmove@plt+0x3440>
#     69e4: f9476e11     	ldr	x17, [x16, #0xed8]
#     69e8: 913b6210     	add	x16, x16, #0xed8
#     69ec: d61f0220     	br	x17
#
# 00000000000069f0 <getenv@plt>:
#     69f0: 90000030     	adrp	x16, 0xa000 <memmove@plt+0x3440>
#     69f4: f9477211     	ldr	x17, [x16, #0xee0]
#     69f8: 913b8210     	add	x16, x16, #0xee0
#     69fc: d61f0220     	br	x17
#
# 0000000000006a00 <strtol@plt>:
#     6a00: 90000030     	adrp	x16, 0xa000 <memmove@plt+0x3440>
#     6a04: f9477611     	ldr	x17, [x16, #0xee8]
#     6a08: 913ba210     	add	x16, x16, #0xee8
#     6a0c: d61f0220     	br	x17
#
# 0000000000006a10 <strlen@plt>:
#     6a10: 90000030     	adrp	x16, 0xa000 <memmove@plt+0x3440>
#     6a14: f9477a11     	ldr	x17, [x16, #0xef0]
#     6a18: 913bc210     	add	x16, x16, #0xef0
#     6a1c: d61f0220     	br	x17
#
# 0000000000006a20 <fprintf@plt>:
#     6a20: 90000030     	adrp	x16, 0xa000 <memmove@plt+0x3440>
#     6a24: f9477e11     	ldr	x17, [x16, #0xef8]
#     6a28: 913be210     	add	x16, x16, #0xef8
#     6a2c: d61f0220     	br	x17
#
# 0000000000006a30 <__errno@plt>:
#     6a30: 90000030     	adrp	x16, 0xa000 <memmove@plt+0x3440>
#     6a34: f9478211     	ldr	x17, [x16, #0xf00]
#     6a38: 913c0210     	add	x16, x16, #0xf00
#     6a3c: d61f0220     	br	x17
#
# 0000000000006a40 <strerror@plt>:
#     6a40: 90000030     	adrp	x16, 0xa000 <memmove@plt+0x3440>
#     6a44: f9478611     	ldr	x17, [x16, #0xf08]
#     6a48: 913c2210     	add	x16, x16, #0xf08
#     6a4c: d61f0220     	br	x17
#
# 0000000000006a50 <__stack_chk_fail@plt>:
#     6a50: 90000030     	adrp	x16, 0xa000 <memmove@plt+0x3440>
#     6a54: f9478a11     	ldr	x17, [x16, #0xf10]
#     6a58: 913c4210     	add	x16, x16, #0xf10
#     6a5c: d61f0220     	br	x17
#
# 0000000000006a60 <malloc@plt>:
#     6a60: 90000030     	adrp	x16, 0xa000 <memmove@plt+0x3440>
#     6a64: f9478e11     	ldr	x17, [x16, #0xf18]
#     6a68: 913c6210     	add	x16, x16, #0xf18
#     6a6c: d61f0220     	br	x17
#
# 0000000000006a70 <free@plt>:
#     6a70: 90000030     	adrp	x16, 0xa000 <memmove@plt+0x3440>
#     6a74: f9479211     	ldr	x17, [x16, #0xf20]
#     6a78: 913c8210     	add	x16, x16, #0xf20
#     6a7c: d61f0220     	br	x17
#
# 0000000000006a80 <fputc@plt>:
#     6a80: 90000030     	adrp	x16, 0xa000 <memmove@plt+0x3440>
#     6a84: f9479611     	ldr	x17, [x16, #0xf28]
#     6a88: 913ca210     	add	x16, x16, #0xf28
#     6a8c: d61f0220     	br	x17
#
# 0000000000006a90 <exit@plt>:
#     6a90: 90000030     	adrp	x16, 0xa000 <memmove@plt+0x3440>
#     6a94: f9479a11     	ldr	x17, [x16, #0xf30]
#     6a98: 913cc210     	add	x16, x16, #0xf30
#     6a9c: d61f0220     	br	x17
#
# 0000000000006aa0 <fputs@plt>:
#     6aa0: 90000030     	adrp	x16, 0xa000 <memmove@plt+0x3440>
#     6aa4: f9479e11     	ldr	x17, [x16, #0xf38]
#     6aa8: 913ce210     	add	x16, x16, #0xf38
#     6aac: d61f0220     	br	x17
#
# 0000000000006ab0 <abort@plt>:
#     6ab0: 90000030     	adrp	x16, 0xa000 <memmove@plt+0x3440>
#     6ab4: f947a211     	ldr	x17, [x16, #0xf40]
#     6ab8: 913d0210     	add	x16, x16, #0xf40
#     6abc: d61f0220     	br	x17
#
# 0000000000006ac0 <pthread_mutex_destroy@plt>:
#     6ac0: 90000030     	adrp	x16, 0xa000 <memmove@plt+0x3440>
#     6ac4: f947a611     	ldr	x17, [x16, #0xf48]
#     6ac8: 913d2210     	add	x16, x16, #0xf48
#     6acc: d61f0220     	br	x17
#
# 0000000000006ad0 <pthread_mutex_unlock@plt>:
#     6ad0: 90000030     	adrp	x16, 0xa000 <memmove@plt+0x3440>
#     6ad4: f947aa11     	ldr	x17, [x16, #0xf50]
#     6ad8: 913d4210     	add	x16, x16, #0xf50
#     6adc: d61f0220     	br	x17
#
# 0000000000006ae0 <memset@plt>:
#     6ae0: 90000030     	adrp	x16, 0xa000 <memmove@plt+0x3440>
#     6ae4: f947ae11     	ldr	x17, [x16, #0xf58]
#     6ae8: 913d6210     	add	x16, x16, #0xf58
#     6aec: d61f0220     	br	x17
#
# 0000000000006af0 <pthread_mutex_init@plt>:
#     6af0: 90000030     	adrp	x16, 0xa000 <memmove@plt+0x3440>
#     6af4: f947b211     	ldr	x17, [x16, #0xf60]
#     6af8: 913d8210     	add	x16, x16, #0xf60
#     6afc: d61f0220     	br	x17
#
# 0000000000006b00 <pthread_mutex_lock@plt>:
#     6b00: 90000030     	adrp	x16, 0xa000 <memmove@plt+0x3440>
#     6b04: f947b611     	ldr	x17, [x16, #0xf68]
#     6b08: 913da210     	add	x16, x16, #0xf68
#     6b0c: d61f0220     	br	x17
#
# 0000000000006b10 <pthread_self@plt>:
#     6b10: 90000030     	adrp	x16, 0xa000 <memmove@plt+0x3440>
#     6b14: f947ba11     	ldr	x17, [x16, #0xf70]
#     6b18: 913dc210     	add	x16, x16, #0xf70
#     6b1c: d61f0220     	br	x17
#
# 0000000000006b20 <vsnprintf@plt>:
#     6b20: 90000030     	adrp	x16, 0xa000 <memmove@plt+0x3440>
#     6b24: f947be11     	ldr	x17, [x16, #0xf78]
#     6b28: 913de210     	add	x16, x16, #0xf78
#     6b2c: d61f0220     	br	x17
#
# 0000000000006b30 <unlink@plt>:
#     6b30: 90000030     	adrp	x16, 0xa000 <memmove@plt+0x3440>
#     6b34: f947c211     	ldr	x17, [x16, #0xf80]
#     6b38: 913e0210     	add	x16, x16, #0xf80
#     6b3c: d61f0220     	br	x17
#
# 0000000000006b40 <lseek@plt>:
#     6b40: 90000030     	adrp	x16, 0xa000 <memmove@plt+0x3440>
#     6b44: f947c611     	ldr	x17, [x16, #0xf88]
#     6b48: 913e2210     	add	x16, x16, #0xf88
#     6b4c: d61f0220     	br	x17
#
# 0000000000006b50 <close@plt>:
#     6b50: 90000030     	adrp	x16, 0xa000 <memmove@plt+0x3440>
#     6b54: f947ca11     	ldr	x17, [x16, #0xf90]
#     6b58: 913e4210     	add	x16, x16, #0xf90
#     6b5c: d61f0220     	br	x17
#
# 0000000000006b60 <read@plt>:
#     6b60: 90000030     	adrp	x16, 0xa000 <memmove@plt+0x3440>
#     6b64: f947ce11     	ldr	x17, [x16, #0xf98]
#     6b68: 913e6210     	add	x16, x16, #0xf98
#     6b6c: d61f0220     	br	x17
#
# 0000000000006b70 <write@plt>:
#     6b70: 90000030     	adrp	x16, 0xa000 <memmove@plt+0x3440>
#     6b74: f947d211     	ldr	x17, [x16, #0xfa0]
#     6b78: 913e8210     	add	x16, x16, #0xfa0
#     6b7c: d61f0220     	br	x17
#
# 0000000000006b80 <ftruncate@plt>:
#     6b80: 90000030     	adrp	x16, 0xa000 <memmove@plt+0x3440>
#     6b84: f947d611     	ldr	x17, [x16, #0xfa8]
#     6b88: 913ea210     	add	x16, x16, #0xfa8
#     6b8c: d61f0220     	br	x17
#
# 0000000000006b90 <vfprintf@plt>:
#     6b90: 90000030     	adrp	x16, 0xa000 <memmove@plt+0x3440>
#     6b94: f947da11     	ldr	x17, [x16, #0xfb0]
#     6b98: 913ec210     	add	x16, x16, #0xfb0
#     6b9c: d61f0220     	br	x17
#
# 0000000000006ba0 <memcpy@plt>:
#     6ba0: 90000030     	adrp	x16, 0xa000 <memmove@plt+0x3440>
#     6ba4: f947de11     	ldr	x17, [x16, #0xfb8]
#     6ba8: 913ee210     	add	x16, x16, #0xfb8
#     6bac: d61f0220     	br	x17
#
# 0000000000006bb0 <memchr@plt>:
#     6bb0: 90000030     	adrp	x16, 0xa000 <memmove@plt+0x3440>
#     6bb4: f947e211     	ldr	x17, [x16, #0xfc0]
#     6bb8: 913f0210     	add	x16, x16, #0xfc0
#     6bbc: d61f0220     	br	x17
#
# 0000000000006bc0 <memmove@plt>:
#     6bc0: 90000030     	adrp	x16, 0xa000 <memmove@plt+0x3440>
#     6bc4: f947e611     	ldr	x17, [x16, #0xfc8]
#     6bc8: 913f2210     	add	x16, x16, #0xfc8
#     6bcc: d61f0220     	br	x17
